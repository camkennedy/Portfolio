# %% [markdown]
# # Music Churn:  Data Preparation / Feature Extraction Notebook
# Python Notebook 1 of 3
#
# ## W207, Final Project
# Spring, 2018
#
# Team:  Cameron Kennedy, Gaurav Khanna, Aaron Olson
#
#
# ## Overview of Notebooks
# For this project, the team created 3 separate Jupyter Notebooks to document its work:
#
# **1) Data Preparation / Feature Extraction Notebook:**  This notebook gives an overview of the project, and then takes the raw data, performs some initial exploration, and generates features for the predictive models.  It also performs a brief exploratory data analysis on the feature set.  The output this notebook output a .pkl file of features for the second notebook to read, which saves considerable time when building the models.
#
# **2) Predictive Modeling Notebook:**  This notebook reads the .pkl file, builds machine learning models to predict user churn, calculates and calibrates churn probabilities, and generates a projected economic impact of users who leave.
#
# **3) Initial Data Sourcing and Validation Notebook (HTML file):**  This is a static notebook (uploaded as HTML file - not intended for executing code) that documents two other aspects of the project that don't logically fit in either of the first two notebooks:
#
# * First, it contains the initial data extraction code used in Google BigQuery to reduce the data set from ~30GB down to ~1.6GB, to enable it to run on local machines.
#
# * Second, it contains some code that performs data integrity checks, validating that the items extracted in our smaller data set approximately match those in the full data set (e.g., same level of churn, the same timeframe, etc.)
#
# ## Table of Contents (this notebook only)
#
# 1. Project Overview
# 2. Data Set Overview
# 3. Initial Data Loading
# 4. User Logs Data: Preparation and Feature Extraction
# 5. Transaction Data: Preparation and Feature Extraction
# 6. Joining Features and Data Manipulation
# 7. Quick Exploratory Data Analysis
# 8. Writing Output

# %% [markdown]
# # 1. Project Overview
# This dataset is comprised of data collected by WSDM regarding a music streaming subscription available through KKBOX.
#
# ## Project Goals:
# The project aims to accomplish the following goals:
#
# * Create a model to predict customer churn from usage and transaction data
# * Create an economic model for retention
# * Recommend a process for keeping the churn and economic retention models updated with latest information

# %% [markdown]
# # 2. Data Set Overview
#
# The initial data set contains 24 variables (25 input variables and 1 variable to predict), these are spread across 4 tables.  Additional details:
#
# * **Original format:** csv
# * **Total Size:** 31.14 GB, reduced to 1.6GB for analysis on local machines.
# * ** User Count:** 1.02 million labeled users contained in the Train table (88,544 users after reduction)
# * **Date Range:** The data of customer usage and trasactions with the service spans 26 months, from Jan. 2015 to Feb. 2017.  However, one of the data fields is initial date users joined the service, with dates ranging from 2004 to 2017.
# * **Balance:** Approximately 6% of users in the data churned (positive labels); the remaining 94% stayed (negative labels).
#
# Listed below are the tables and variables or features available for study:

# %% [markdown]
# ## Table: Transactions
# This table contains transaction data for each user. Each row is a payment transaction.
#
# * **Data Shape:** 21.5M rows X 9 columns
# * **Data Size:** 1.6GB
#
# ### Data Fields:
#
# * **Msno:** User ID
# * **Payment_method_id:** Payment Method
# * **Payment_plan_days:** Length of plan
# * **Plan_list_price:** Price for the plan
# * **Actual_amount_paid:** Amount paid
# * **Is_auto_renew:** T/F flag determining whether membership is auto-renew or not
# * **Transaction Date:** Date of purchase
# * **Membership_expire_date:** Expiry date
# * **Is_cancel:** T/F flag determining whether or not the user canceled service. This field is correlated with the is_churn category, though it isn’t identical, as it also captures users who change service.

# %% [markdown]
# ## Table: User Logs
# This table lists who, how, and when users used the service.  Each row is a unique user-date combination.
#
# * **Data Shape:** 392M rows X 9 columns
# * **Data Size:** 29.1GB
#
# ### Data Fields:
#
# * **Msno:** User ID
# * **Date:** Date of the logged activity
# * **Num_25:** Number of songs played < 25% of song length
# * **Num_50:** Number of songs played between 25% and 50%
# * **Num_75:** Number of songs played between 50% and 75%
# * **Num_985:** Number of songs played between 75% and 98.5%
# * **Num_100:** Number of songs played between 98.5% and 100%
# * **Num_unq:** Number of unique songs played
# * **Total_secs:** Total seconds played

# %% [markdown]
# ## Table: Members
# Demographic data on each user.  Each row represents a unique user.
#
# * **Data Shape:** 6.8M rows X 6 columns
# * **Data Size:** 0.4GB
#
# ### Data Fields:
#
# * **Msno:** User ID
# * **City:** City of the user
# * **BD:** Age of the user
# * **Gender:** Male, Female or Blank
# * **Registered_via:** Registration method
# * **Registration_init_time:** Initial time of registration
# * **Expiration_date:** Expiration of membership

# %% [markdown]
# ## Table: Train
# Labels of which users churned.  Each row represents a unique user.
# * **Data Shape:** 1.0M rows X 2 columns
# * **Data Size:** 45MB
#
# ### Data Fields:
#
# * **Msno:** User ID
# * **Is_churn:**  T/F flag variable we are trying to predict.

# %% [markdown]
# # 3. Initial Data Loading
# This analysis is performed in the cells below.

# %%
#Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Set initial parameter(s)
pd.set_option('display.max_rows', 200)
pd.options.display.max_columns = 2000

# %% [markdown]
# Loading the data indexing with the primary key (MSNO: String like/Object, represents the user)

# %%
#Load the data
members = pd.read_csv('members_filtered.csv')
transactions = pd.read_csv('transactions_filtered.csv')
user_logs = pd.read_csv('user_logs_filtered.csv')
labels = pd.read_csv('labels_filtered.csv')

#Set indices
members.set_index('msno', inplace = True)
labels.set_index('msno', inplace = True)

user_logs.head()
# Out:
#                                            msno      date  num_25  num_50  \
# 0  MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  20170217      37       2
# 1  o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  20160209      36       5
# 2  6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  20151210      26       9
# 3  Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  20161025      22       8
# 4  zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  20160904      26       3
#
#    num_75  num_985  num_100  num_unq  total_secs
# 0       2        3       30       66    9022.818
# 1       2        3       48       71   13895.453
# 2       3        0       51       54   13919.805
# 3       4        2       49       75   15147.842
# 4       1        0       39       60   10558.829

# %% [markdown]
# Performing a quick inspection of the data:

# %%
print('Transactions: \n')
transactions.info()

print('User Logs: \n')
user_logs.info()

print('Members: \n')
members.info()

print('User Logs:')
labels.info()
# Out:
# Transactions:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1353459 entries, 0 to 1353458
# Data columns (total 9 columns):
# msno                      1353459 non-null object
# payment_method_id         1353459 non-null int64
# payment_plan_days         1353459 non-null int64
# plan_list_price           1353459 non-null int64
# actual_amount_paid        1353459 non-null int64
# is_auto_renew             1353459 non-null int64
# transaction_date          1353459 non-null int64
# membership_expire_date    1353459 non-null int64
# is_cancel                 1353459 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 92.9+ MB
# User Logs:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19710631 entries, 0 to 19710630
# Data columns (total 9 columns):
# msno          object
# date          int64
# num_25        int64
# num_50        int64
# num_75        int64
# num_985       int64
# num_100       int64
# num_unq       int64
# total_secs    float64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 1.3+ GB
# Members:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 89473 entries, mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg= to EFbHYa9/MiKYiyrl05cZ34Cky0FDeHxTYij0pXwkr2A=
# Data columns (total 5 columns):
# city                      89473 non-null int64
# bd                        89473 non-null int64
# gender                    46137 non-null object
# registered_via            89473 non-null int64
# registration_init_time    89473 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 4.1+ MB
# User Logs:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99825 entries, 3lh94wH+UPK7ENgnA5svzFMYfJJRMZHU/WjgvhRJPzc= to DIgxCOJBeanFdqLOOPMTzwwkqgREVG+g1pwfY5LWvC4=
# Data columns (total 1 columns):
# is_churn    99825 non-null int64
# dtypes: int64(1)
# memory usage: 1.5+ MB

# %% [markdown]
# Helper routine to format the date for visualization:

# %%
def pd_to_date(df_col):
    """Function to convert a pandas dataframe column from %Y%m%d format to datetime format.
    
    Args:
        df_col (column in a pandas dataframe):  The column to be changed.
        
    Returns:
        The same column in datetime format.
        
    """
    df_col = pd.to_datetime(df_col, format = '%Y%m%d')
    return df_col

# %%
#Convert date column to date format
user_logs['date'] = pd_to_date(user_logs['date'])

# %% [markdown]
# The next two sections prepare the 2 major data tables/frames (User Logs & Transactions) independently and then bring them together for analysis.

# %% [markdown]
# # 4. User Logs Data:  Preparation and Feature Extraction
#
# We first create our groupby object to ultimately aggregate data by users:

# %%
#Create our groupby user object 
user_logs_gb = user_logs.groupby(['msno'], sort=False)

# %% [markdown]
# The next cell creates three new columns:
#
# * **max_date:**  The latest date each user has a transaction
# * **days_before_max_date:**  The the number of days between the max date and the date of the current record.
# * **listening_tenure:**  The the number of days between the max date and min date of the current user.  The hypothesis for this feature is that a user who's been using the service for a long time may be less likely to churn than one who's been using the service for a short time.

# %%
#This cell is slow

#Append max date to every row in main table
user_logs['max_date'] = user_logs_gb['date'].transform('max')
user_logs['days_before_max_date'] = (user_logs['max_date'] - user_logs['date']).apply(lambda x: x.days)
    #The .apply(lambda...  just converts it from datetime to an integer, for easier comparisons later.

#Generate user's first date, last date, and tenure
#Also, the user_logs_features table will be the primary table to return from the transactions table
user_logs_features = (user_logs_gb
    .agg({'date':['max', 'min', lambda x: (max(x) - min(x)).days]})  #.days converts to int
    .rename(columns={'max': 'max_date', 'min': 'min_date','<lambda>':'listening_tenure'})
                      )
#Add a 3rd level, used for joining data later
user_logs_features = pd.concat([user_logs_features], axis=1, keys=['date_features'])

# %% [markdown]
# Let's take a look at our initial users table:

# %%
user_logs_features.head()
# Out:
#                                              date_features             \
#                                                       date
#                                                   max_date   min_date
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=    2017-02-27 2015-07-11
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    2017-02-07 2015-03-10
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=    2017-02-17 2015-01-01
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=    2017-02-28 2016-09-08
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=    2017-02-13 2015-01-01
#
#
#
#                                              listening_tenure
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=              597
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=              700
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=              778
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=              173
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=              774

# %% [markdown]
# We now create features to look at patters of usage over the past X days, where X is days_before_max_date, to see what a user has been doing "lately".  We apply this rationale to all of the usage columns in the user_logs table, giving us combinations of the following elements of our data:
#
# * Number of songs played < Y% of song length, where Y is 100, 985, 75, 50, and 25, plus the number of unique songs and total seconds played.
# * Activity over the last day, last 7, 30, 90, 180, 365, and total days, noting that the date range is relative to user's most recent activity.
#
# For each of these combinations, we calulate (using groupby and aggregate) both the sum and mean of each feature.  And finally we also create a single, total count column (number of rows) for the past number of days.  In total, this generates 120 features, which we then append to the user_logs_features table above.

# %%
#Create Features:
    # Total X=(seconds, 100, 985, 75, 50, 25, unique), avg per day of X, maybe median per day of X
    # Last day, last 7 days, last 30 days, last 90, 180, 365, total (note last day is relative to user)
    
for num_days in [1, 7, 14, 31, 90, 180, 365, 9999]:
    #Create groupby object for items with x days
    ul_gb_xdays = (user_logs.loc[(user_logs['days_before_max_date'] < num_days)]
                   .groupby(['msno'], sort=False))

    #Generate sum and mean (and count, once) for all the user logs stats
    past_xdays_by_user = (ul_gb_xdays
        .agg({'num_unq':['sum', 'mean', 'count'],
              'total_secs':['sum', 'mean'],
              'num_25':['sum', 'mean'],
              'num_50':['sum', 'mean'],
              'num_75':['sum', 'mean'],
              'num_985':['sum', 'mean'],
              'num_100':['sum', 'mean'],
             })
                      )
    #Append level header
    past_xdays_by_user = pd.concat([past_xdays_by_user], axis=1, keys=['within_days_' + str(num_days)])

    #Join (append) to user_logs_features table
    user_logs_features = user_logs_features.join(past_xdays_by_user, how='inner')

# %% [markdown]
# Taking a quick look at our table now:

# %%
user_logs_features.head()
# Out:
#                                              date_features             \
#                                                       date
#                                                   max_date   min_date
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=    2017-02-27 2015-07-11
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    2017-02-07 2015-03-10
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=    2017-02-17 2015-01-01
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=    2017-02-28 2016-09-08
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=    2017-02-13 2015-01-01
#
#                                                               within_days_1  \
#                                                                     num_unq
#                                              listening_tenure           sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=              597            17
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=              700             1
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=              778            13
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=              173            86
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=              774            22
#
#                                                                                \
#                                                         total_secs
#                                              mean count        sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=   17     1  29802.123  29802.123
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    1     1    274.176    274.176
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   13     1  10363.972  10363.972
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   86     1  21094.770  21094.770
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   22     1   2803.117   2803.117
#
#                                                                              \
#                                              num_25      num_50      num_75
#                                                 sum mean    sum mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     17   17      1    1      0
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=      0    0      0    0      0
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=      5    5      1    1      1
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     10   10      6    6      7
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=      9    9      0    0      3
#
#                                                                              \
#                                                   num_985      num_100
#                                              mean     sum mean     sum mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=    0       1    1     115  115
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    0       0    0       1    1
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=    1       4    4      41   41
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=    7       4    4      72   72
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=    3       0    0      10   10
#
#                                              within_days_7                   \
#                                                    num_unq
#                                                        sum       mean count
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=           161  26.833333     6
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=           161  26.833333     6
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=           219  43.800000     5
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=           133  26.600000     5
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            50  12.500000     4
#
#                                                                              \
#                                              total_secs              num_25
#                                                     sum         mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  72502.206  12083.70100     99
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  40311.015   6718.50250     52
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  68118.548  13623.70960     25
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  32936.237   6587.24740     18
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   7935.679   1983.91975     17
#
#                                                                           \
#                                                         num_50
#                                                    mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  16.500000     13  2.166667
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   8.666667      7  1.166667
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   5.000000      6  1.200000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   3.600000      8  1.600000
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   4.250000      2  0.500000
#
#                                                                              \
#                                              num_75           num_985
#                                                 sum      mean     sum  mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     11  1.833333       9  1.50
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=      7  1.166667      15  2.50
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=      6  1.200000       7  1.40
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=      7  1.400000       8  1.60
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=      3  0.750000       1  0.25
#
#                                                                  \
#                                              num_100
#                                                  sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     275  45.833333
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     137  22.833333
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=     289  57.800000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     112  22.400000
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=      31   7.750000
#
#                                              within_days_14                   \
#                                                     num_unq
#                                                         sum       mean count
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=            478  39.833333    12
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=            253  25.300000    10
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=            480  48.000000    10
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=            313  31.300000    10
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            101  14.428571     7
#
#                                                                                \
#                                               total_secs               num_25
#                                                      sum          mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  154157.897  12846.491417    207
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   65631.235   6563.123500     84
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  121094.373  12109.437300     83
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   72406.047   7240.604700     86
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   17605.267   2515.038143     41
#
#                                                                           \
#                                                         num_50
#                                                    mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  17.250000     24  2.000000
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   8.400000     16  1.600000
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   8.300000     24  2.400000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   8.600000     18  1.800000
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   5.857143      5  0.714286
#
#                                                                        \
#                                              num_75           num_985
#                                                 sum      mean     sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     16  1.333333      19
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     16  1.600000      25
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=      9  0.900000      11
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     11  1.100000      13
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=      4  0.571429       1
#
#                                                                            \
#                                                        num_100
#                                                   mean     sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  1.583333     595  49.583333
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  2.500000     218  21.800000
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  1.100000     498  49.800000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  1.300000     251  25.100000
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  0.142857      71  10.142857
#
#                                              within_days_31                   \
#                                                     num_unq
#                                                         sum       mean count
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=           1040  41.600000    25
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=            811  38.619048    21
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=            870  43.500000    20
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=            493  21.434783    23
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            301  21.500000    14
#
#                                                                                \
#                                               total_secs               num_25
#                                                      sum          mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  299571.033  11982.841320    448
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  201286.586   9585.075524    236
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  210674.360  10533.718000    190
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  114170.059   4963.915609    126
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   40235.862   2873.990143    148
#
#                                                                           \
#                                                         num_50
#                                                    mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  17.920000     53  2.120000
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  11.238095     43  2.047619
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   9.500000     37  1.850000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   5.478261     27  1.173913
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  10.571429     15  1.071429
#
#                                                                        \
#                                              num_75           num_985
#                                                 sum      mean     sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     27  1.080000      43
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     38  1.809524      53
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=     20  1.000000      28
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     16  0.695652      16
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=      9  0.642857       7
#
#                                                                            \
#                                                        num_100
#                                                   mean     sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  1.720000    1153  46.120000
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  2.523810     699  33.285714
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  1.400000     827  41.350000
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  0.695652     395  17.173913
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  0.500000     152  10.857143
#
#                                              within_days_90                   \
#                                                     num_unq
#                                                         sum       mean count
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=           2723  43.919355    62
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=           1428  33.209302    43
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=           2390  44.259259    54
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=           2060  34.915254    59
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            759  23.000000    33
#
#                                                                                \
#                                               total_secs               num_25
#                                                      sum          mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  610185.373   9841.699565   1227
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  408254.891   9494.299791    460
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  604775.769  11199.551278    490
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  406402.278   6888.174203    781
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  124239.481   3764.832758    284
#
#                                                                           \
#                                                         num_50
#                                                    mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  19.790323    222  3.580645
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  10.697674     78  1.813953
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   9.074074    116  2.148148
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  13.237288    116  1.966102
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   8.606061     28  0.848485
#
#                                                                        \
#                                              num_75           num_985
#                                                 sum      mean     sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=    103  1.661290     132
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     69  1.604651     101
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=     79  1.462963      92
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     75  1.271186      69
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=     21  0.636364      24
#
#                                                                            \
#                                                        num_100
#                                                   mean     sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  2.129032    2244  36.193548
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  2.348837    1430  33.255814
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  1.703704    2318  42.925926
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  1.169492    1404  23.796610
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  0.727273     466  14.121212
#
#                                              within_days_180                   \
#                                                      num_unq
#                                                          sum       mean count
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=            5805  47.975207   121
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=            1648  32.313725    51
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=            4427  41.764151   106
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=            3840  37.281553   103
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            2722  32.023529    85
#
#                                                                          \
#                                                total_secs
#                                                       sum          mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  1195064.265   9876.564174
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   487842.759   9565.544294
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  1186775.568  11195.995925
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   799700.121   7764.078845
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   461324.690   5427.349294
#
#                                                                        \
#                                              num_25            num_50
#                                                 sum       mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=   2792  23.074380    543
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    495   9.705882     92
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=    750   7.075472    212
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   1387  13.466019    219
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   1185  13.941176     96
#
#                                                                          \
#                                                        num_75
#                                                   mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  4.487603    261  2.157025
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  1.803922     76  1.490196
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  2.000000    143  1.349057
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  2.126214    159  1.543689
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  1.129412     70  0.823529
#
#                                                                         \
#                                              num_985           num_100
#                                                  sum      mean     sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     252  2.082645    4267
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     105  2.058824    1735
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=     179  1.688679    4631
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     168  1.631068    2696
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=     123  1.447059    1712
#
#                                                         within_days_365  \
#                                                                 num_unq
#                                                    mean             sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  35.264463           10396
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  34.019608            3255
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  43.688679            9683
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  26.174757            3840
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  20.141176            9576
#
#                                                                             \
#                                                                 total_secs
#                                                    mean count          sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  45.004329   231  1989225.131
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  29.062500   112   968253.587
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  41.917749   231  2677487.134
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  37.281553   103   799700.121
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  46.712195   205  1931032.095
#
#                                                                               \
#                                                            num_25
#                                                       mean    sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=   8611.364203   4768  20.640693
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   8645.121312   1114   9.946429
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  11590.853394   1323   5.727273
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   7764.078845   1387  13.466019
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   9419.668756   3431  16.736585
#
#                                                                       \
#                                              num_50           num_75
#                                                 sum      mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=   1243  5.380952    513
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    206  1.839286    164
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=    425  1.839827    340
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=    219  2.126214    159
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=    401  1.956098    278
#
#                                                                           \
#                                                        num_985
#                                                   mean     sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  2.220779     479  2.073593
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  1.464286     230  2.053571
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  1.471861     396  1.714286
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  1.543689     168  1.631068
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  1.356098     376  1.834146
#
#                                                                  \
#                                              num_100
#                                                  sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=    6908  29.904762
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=    3430  30.625000
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   10499  45.450216
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=    2696  26.174757
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=    7359  35.897561
#
#                                              within_days_9999             \
#                                                       num_unq
#                                                           sum       mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=            17549  46.181579
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=             7475  25.775862
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=            17589  35.605263
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=             3840  37.281553
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=            16913  57.921233
#
#                                                                                \
#                                                      total_secs
#                                              count          sum          mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=   380  3134336.415   8248.253724
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   290  2826851.820   9747.764897
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   494  4836694.885   9790.880334
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   103   799700.121   7764.078845
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   292  3583828.437  12273.385058
#
#                                                                        \
#                                              num_25            num_50
#                                                 sum       mean    sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  10198  26.836842   2395
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=   3059  10.548276    692
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=   2799   5.665992   1023
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=   1387  13.466019    219
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=   5126  17.554795    591
#
#                                                                          \
#                                                        num_75
#                                                   mean    sum      mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  6.302632    972  2.557895
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  2.386207    535  1.844828
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  2.070850    772  1.562753
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  2.126214    159  1.543689
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  2.023973    440  1.506849
#
#                                                                         \
#                                              num_985           num_100
#                                                  sum      mean     sum
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=     806  2.121053   10495
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=     567  1.955172   10075
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=     770  1.558704   18443
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=     168  1.631068    2696
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=     559  1.914384   13815
#
#
#
#                                                    mean
# msno
# MVODUEUlSocm1sXa+zVGpJazPrRFiD4IzEQk0QCdg4U=  27.618421
# o3Dg7baW8dXq7Jq7NzlVrWG4mZNVvqp62oWBDO/ybeE=  34.741379
# 6ERcO7aqAKvrQ2CAvah79dVC7tJVZSjNti1MBfpNVW4=  37.334008
# Xt9VAHNtHuST21tkcZSnGKjwv8vF8/COnsf6z28+fKk=  26.174757
# zSgTJqoosTiFF7ZZi1DPTHgxLbnd99IgOEsTIDCcZHc=  47.311644

# %% [markdown]
# Good, we get the expected number of columns.

# %% [markdown]
# # 5. Transaction Data: Preparation and Feature Extraction
# Having completed feature extraction for user logs, we now move on to creating features for the transaction data.
#
# We begin grouping the data by user.

# %%
# Grouping by the member (msno)
transactions_gb = transactions.sort_values(["transaction_date"]).groupby(['msno'])

# How many groups i.e. members i.e. msno's. We're good if this is the same number as the members table
print('%d Groups/msnos' %(len(transactions_gb.groups)))
print('%d Features' %(len(transactions.columns)))
# Out:
# 99825 Groups/msnos
# 9 Features

# %% [markdown]
# We plan to create the following features from the transactions table:
# * Simple featuers from the latest transaction
#     * Plan no of days
#     * plan total amount paid
#     * plan list price
#     * Is_auto_renew
#     * is_cancel
# * Synthetic features from the latest transaction
#     * Plan actual amount paid/day
# * Aggregate values
#     * Total number of plan days
#     * Total of all the amounts paid for the plan
# * Comparing transactions
#     * Plan day difference among the latest and previous transaction
#     * Amount paid/day difference among the latest and previous transaction

# %% [markdown]
# We begin by creating the total_plan_days and total_amount_paid:

# %%
# Features: Total_plan_days, Total_amount_paid
transactions_features = (transactions_gb
    .agg({'payment_plan_days':'sum', 'actual_amount_paid':'sum' })
    .rename(columns={'payment_plan_days': 'total_plan_days', 'actual_amount_paid': 'total_amount_paid',})
          )
print('%d Entries in the DF: ' %(len(transactions_features)))
print('%d Features' %(len(transactions_features.columns)))

transactions_features.head()
# Out:
# 99825 Entries in the DF:
# 2 Features
#                                               total_plan_days  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=              543
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=               90
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=              513
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=              270
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=              457
#
#                                               total_amount_paid
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=               2831
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                297
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=               2682
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                891
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=               2235

# %% [markdown]
# Next, we add amount_paid_per_day for a user's entire tenure:

# %%
# Plan actual amount paid/day for all the transactions by a user
# Adding the collumn amount_paid_per_day
transactions_features['amount_paid_per_day'] = (transactions_features['total_amount_paid']
                                                /transactions_features['total_plan_days'])

print('%d Entries in the DF: ' %(len(transactions_features)))
print('%d Features' %(len(transactions_features.columns)))

transactions_features.head()
# Out:
# 99825 Entries in the DF:
# 3 Features
#                                               total_plan_days  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=              543
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=               90
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=              513
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=              270
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=              457
#
#                                               total_amount_paid  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=               2831
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                297
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=               2682
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                891
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=               2235
#
#                                               amount_paid_per_day
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=             5.213628
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=             3.300000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=             5.228070
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=             3.300000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=             4.890591

# %% [markdown]
# Next, we add latest_payment_method_id, latest_plan_days, latest_plan_list_price, latest_amount_paid, latest_auto_renew, latest_transaction_date, latest_expire_date, and latest_is_cancel.  We accomplish this by picking from the bottom of the ordered (by date) rows in groups.

# %%
# Features: latest transaction, renaming the collumns
# V1- Fixed the name for plan_list_price collumn (now called latest_plan_list_price)

latest_transaction= transactions_gb.tail([1]).rename(columns={'payment_method_id': 'latest_payment_method_id',
                                                                  'payment_plan_days': 'latest_plan_days',
                                                                  'plan_list_price': 'latest_plan_list_price',
                                                                  'actual_amount_paid': 'latest_amount_paid',
                                                                  'is_auto_renew': 'latest_auto_renew', 
                                                                  'transaction_date': 'latest_transaction_date',
                                                                  'membership_expire_date': 'latest_expire_date',
                                                                  'is_cancel': 'latest_is_cancel' })

# Index by msno
latest_transaction.set_index('msno', inplace = True)

print('%d Entries in the DF: ' %(len(latest_transaction)))
print('%d Features' %(len(latest_transaction.columns)))

latest_transaction.head()
# Out:
# 99825 Entries in the DF:
# 8 Features
#                                               latest_payment_method_id  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                        38
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                        38
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                        32
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                        38
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                        38
#
#                                               latest_plan_days  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                30
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                30
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=               410
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                30
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=               360
#
#                                               latest_plan_list_price  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                     149
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                     149
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                    1788
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                     149
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                    1200
#
#                                               latest_amount_paid  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 149
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 149
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                1788
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 149
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                1200
#
#                                               latest_auto_renew  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                  0
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                  0
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                  0
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                  0
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                  0
#
#                                               latest_transaction_date  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 20150102
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 20150102
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                 20150104
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 20150120
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                 20150123
#
#                                               latest_expire_date  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=            20150503
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=            20150702
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=            20170213
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=            20170103
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=            20170212
#
#                                               latest_is_cancel
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 0
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 0
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                 0
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 0
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                 0

# %% [markdown]
# Next, we add latest_amount_paid_per_day:

# %%
# Plan actual amount paid/day for the latest transaction
# Adding the collumn amount_paid_per_day

latest_transaction['latest_amount_paid_per_day'] = (latest_transaction['latest_amount_paid']
                                                /latest_transaction['latest_plan_days'])

print('%d Entries in the DF: ' %(len(latest_transaction)))
print('%d Features' %(len(latest_transaction.columns)))

latest_transaction.head()
# Out:
# 99825 Entries in the DF:
# 9 Features
#                                               latest_payment_method_id  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                        38
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                        38
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                        32
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                        38
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                        38
#
#                                               latest_plan_days  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                30
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                30
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=               410
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                30
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=               360
#
#                                               latest_plan_list_price  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                     149
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                     149
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                    1788
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                     149
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                    1200
#
#                                               latest_amount_paid  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 149
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 149
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                1788
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 149
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                1200
#
#                                               latest_auto_renew  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                  0
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                  0
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                  0
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                  0
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                  0
#
#                                               latest_transaction_date  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 20150102
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 20150102
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                 20150104
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 20150120
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                 20150123
#
#                                               latest_expire_date  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=            20150503
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=            20150702
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=            20170213
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=            20170103
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=            20170212
#
#                                               latest_is_cancel  \
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                 0
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                 0
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                 0
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                 0
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                 0
#
#                                               latest_amount_paid_per_day
# msno
# z1Lm/BlRQraiaWJ7RaQWe0+l0Z40ACj7W+zk29FiaS4=                    4.966667
# IwE/pih8PuqrY/rsnoZ/4TazDliyH9S8VWNc2/d7mJg=                    4.966667
# ea9rY0uEPY0ImD2QVbYFb+z3zi5wniKWMUM1V8os7OY=                    4.360976
# plhzwjmNJp0HW04NidfVa35JE216RaFYpSeUCwT11zQ=                    4.966667
# PbSQ2KxR4gRnzjsRd8Up75qMYb70iuMwGk10/jPRljk=                    3.333333

# %% [markdown]
# Next, we compare two different items in our transaction data:
#
# * Plan duration difference among the last 2 transactons
# * Cost difference among the last 2 transactions

# %%
# Getting the 2 latest transactions and grouping by msno again
latest_transaction2_gb = transactions_gb.tail([2]).groupby(['msno'])

# Getting the latest but one transaction
latest2_transaction = latest_transaction2_gb.head([1])

# Index by msno
latest2_transaction.set_index('msno', inplace = True)

# Amount paid per day for the 2nd latest transaction
latest2_transaction['latest2_amount_paid_per_day'] = (latest2_transaction['actual_amount_paid']
                                                /latest2_transaction['payment_plan_days'])

# Difference in the renewal length among the latest 2 transactions
transactions_features['diff_renewal_duration'] = (latest_transaction['latest_plan_days']
                                                - latest2_transaction['payment_plan_days'])

# Different in plan cost among the latest 2 transactions
transactions_features['diff_plan_amount_paid_per_day'] = (latest_transaction['latest_amount_paid_per_day'] 
                                                          - latest2_transaction['latest2_amount_paid_per_day'])

print('%d Entries in the DF: ' %(len(transactions_features)))
print('%d Features' %(len(transactions_features.columns)))

transactions_features.head()
# Out:
# C:\Users\AOlson\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# 99825 Entries in the DF:
# 5 Features
#                                               total_plan_days  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=              543
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=               90
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=              513
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=              270
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=              457
#
#                                               total_amount_paid  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=               2831
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                297
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=               2682
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                891
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=               2235
#
#                                               amount_paid_per_day  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=             5.213628
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=             3.300000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=             5.228070
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=             3.300000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=             4.890591
#
#                                               diff_renewal_duration  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                      0
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                      0
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                      0
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                      0
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                     23
#
#                                               diff_plan_amount_paid_per_day
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                       0.000000
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                       0.000000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                       0.000000
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                       0.000000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                       4.966667

# %% [markdown]
# Finally, we join all the features into a single data frame:

# %%
# Get all transaction features in a single DF
transactions_features = transactions_features.join(latest_transaction, how = 'inner')

# Test
print('%d Entries in the DF: ' %(len(transactions_features)))
print('%d Features' %(len(transactions_features.columns)))

transactions_features.head()
# Out:
# 99825 Entries in the DF:
# 14 Features
#                                               total_plan_days  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=              543
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=               90
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=              513
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=              270
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=              457
#
#                                               total_amount_paid  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=               2831
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                297
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=               2682
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                891
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=               2235
#
#                                               amount_paid_per_day  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=             5.213628
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=             3.300000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=             5.228070
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=             3.300000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=             4.890591
#
#                                               diff_renewal_duration  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                      0
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                      0
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                      0
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                      0
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                     23
#
#                                               diff_plan_amount_paid_per_day  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                       0.000000
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                       0.000000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                       0.000000
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                       0.000000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                       4.966667
#
#                                               latest_payment_method_id  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                        39
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                        41
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                        37
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                        41
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                        41
#
#                                               latest_plan_days  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                30
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                30
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                30
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                30
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                30
#
#                                               latest_plan_list_price  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                     149
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                      99
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                     149
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                      99
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                     149
#
#                                               latest_amount_paid  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 149
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                  99
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                 149
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                  99
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                 149
#
#                                               latest_auto_renew  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                  1
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                  1
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                  1
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                  1
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                  1
#
#                                               latest_transaction_date  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 20170131
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                 20170201
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                 20170201
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                 20170214
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                 20160225
#
#                                               latest_expire_date  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=            20170319
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=            20170301
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=            20170301
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=            20170314
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=            20160225
#
#                                               latest_is_cancel  \
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 0
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                 0
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                 0
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                 0
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                 1
#
#                                               latest_amount_paid_per_day
# msno
# +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                    4.966667
# ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=                    3.300000
# ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=                    4.966667
# ++Ck01c3EF07Ejek2jfXlKut+sEfg+0ry+A5uWeL9vY=                    3.300000
# ++FPL1dXZBXC3Cf6gE0HQiIHg1Pd+DBdK7w52xcUmX0=                    4.966667

# %% [markdown]
# # 6. Joining Features and Data Manipulation
#
# ## Joining Features
#
# Having completed features by user from the User Logs and Transactions tables, we will now join the features from these tables together with the Members and Labels (a.k.a., train) tables into a single data frame for predictive modeling.
#
# First, we'll join the Members and Labels together:

# %%
#Join members and labels files
df_fa = None
df_fa = members.join(labels, how='inner')

df_fa.head()
# Out:
#                                               city  bd gender  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0    NaN              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0    NaN              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0    NaN              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0    NaN              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0    NaN              13
#
#                                               registration_init_time  is_churn
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004         0

# %% [markdown]
# Next, we join the User Logs features table with the combined Members and the Labels table:

# %%
df_fa = df_fa.join(user_logs_features, how='inner')
#Note, the warning is okay, and actually helps us by flattening our column headers.

df_fa.head()
# Out:
# C:\Users\AOlson\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:558: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 3 on the right)
#   warnings.warn(msg, UserWarning)
#                                               city  bd gender  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0    NaN              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0    NaN              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0    NaN              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0    NaN              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0    NaN              13
#
#                                               registration_init_time  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004
#
#                                               is_churn  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=         0
#
#                                              (date_features, date, max_date)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      2017-02-24
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2017-02-27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2017-02-26
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      2017-02-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      2016-10-26
#
#                                              (date_features, date, min_date)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      2017-01-20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2016-09-07
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2016-09-02
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      2016-10-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      2016-10-04
#
#                                               (date_features, date, listening_tenure)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                       35
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                      173
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                      177
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                      123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                       22
#
#                                               (within_days_1, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              1
#
#                                               (within_days_1, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               1
#
#                                               (within_days_1, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                1
#
#                                               (within_days_1, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                           271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           156.204
#
#                                               (within_days_1, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            156.204
#
#                                               (within_days_1, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             0
#
#                                               (within_days_1, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             0
#
#                                               (within_days_1, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             1
#
#                                               (within_days_1, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              1
#
#                                               (within_days_1, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_1, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_7, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            228
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            243
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            121
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             14
#
#                                               (within_days_7, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       32.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       34.714286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       24.200000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.000000
#
#                                               (within_days_7, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                2
#
#                                               (within_days_7, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         32731.138
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         60581.740
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         30054.147
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2399.824
#
#                                               (within_days_7, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4675.876857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        8654.534286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        6010.829400
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1199.912000
#
#                                               (within_days_7, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           140
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            29
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             4
#
#                                               (within_days_7, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      20.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.428571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       5.800000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.000000
#
#                                               (within_days_7, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             5
#
#                                               (within_days_7, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       4.142857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       2.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.500000
#
#                                               (within_days_7, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             4
#
#                                               (within_days_7, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       2.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.000000
#
#                                               (within_days_7, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_7, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.400000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0.000000
#
#                                               (within_days_7, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             95
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            238
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              5
#
#                                               (within_days_7, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       13.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       24.600000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.500000
#
#                                               (within_days_14, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             512
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             489
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             192
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              17
#
#                                               (within_days_14, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        36.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        34.928571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.454545
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         4.250000
#
#                                               (within_days_14, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 4
#
#                                               (within_days_14, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          98422.408
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         122772.792
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          43518.795
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           2630.818
#
#                                               (within_days_14, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         7030.172000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         8769.485143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         3956.254091
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          657.704500
#
#                                               (within_days_14, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            301
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             44
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              5
#
#                                               (within_days_14, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       21.500000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        4.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.250000
#
#                                               (within_days_14, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             71
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              7
#
#                                               (within_days_14, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        5.071429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.750000
#
#                                               (within_days_14, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             34
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              5
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              4
#
#                                               (within_days_14, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.428571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.357143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.000000
#
#                                               (within_days_14, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              42
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_14, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         3.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.785714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.000000
#
#                                               (within_days_14, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             305
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             476
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             174
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               5
#
#                                               (within_days_14, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        21.785714
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        15.818182
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1.250000
#
#                                               (within_days_31, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            1044
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             899
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             457
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             136
#
#                                               (within_days_31, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         6.750000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        36.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        32.107143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        13.600000
#
#                                               (within_days_31, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                28
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                26
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                10
#
#                                               (within_days_31, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           3158.450
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         178909.861
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         231622.820
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         111841.140
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          15562.900
#
#                                               (within_days_31, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          789.612500
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         6169.305552
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         8272.243571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         4301.582308
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1556.290000
#
#                                               (within_days_31, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             33
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            656
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             73
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             80
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             76
#
#                                               (within_days_31, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        8.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       22.620690
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.607143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        3.076923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.600000
#
#                                               (within_days_31, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            135
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             23
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             36
#
#                                               (within_days_31, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4.655172
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.250000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.884615
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        3.600000
#
#                                               (within_days_31, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             61
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             22
#
#                                               (within_days_31, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.103448
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.392857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.200000
#
#                                               (within_days_31, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              74
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               7
#
#                                               (within_days_31, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         2.551724
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.500000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.700000
#
#                                               (within_days_31, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             893
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             456
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              21
#
#                                               (within_days_31, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         2.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        19.689655
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        31.892857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.538462
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         2.100000
#
#                                               (within_days_90, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            4298
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2396
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            1229
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             136
#
#                                               (within_days_90, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        58.876712
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        35.235294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        21.189655
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        13.600000
#
#                                               (within_days_90, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                73
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                68
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                58
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                10
#
#                                               (within_days_90, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         632743.845
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         770040.608
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         287422.839
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          15562.900
#
#                                               (within_days_90, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         8667.723904
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        11324.126588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         4955.566190
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1556.290000
#
#                                               (within_days_90, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2717
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            203
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             76
#
#                                               (within_days_90, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       37.219178
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.647059
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        3.500000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.600000
#
#                                               (within_days_90, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            393
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             81
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             36
#
#                                               (within_days_90, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        5.383562
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1.396552
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        3.600000
#
#                                               (within_days_90, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            188
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             55
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             22
#
#                                               (within_days_90, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.575342
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.948276
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.200000
#
#                                               (within_days_90, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             189
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              33
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              60
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               7
#
#                                               (within_days_90, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         2.589041
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.485294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         1.034483
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.700000
#
#                                               (within_days_90, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2953
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            1145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              21
#
#                                               (within_days_90, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        28.684932
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        43.426471
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        19.741379
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         2.100000
#
#                                               (within_days_180, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              136
#
#                                               (within_days_180, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         13.600000
#
#                                               (within_days_180, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                  6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                 69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 10
#
#                                               (within_days_180, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           15562.900
#
# ...
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                  6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                 69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 10
#
#                                               (within_days_365, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           15562.900
#
#                                               (within_days_365, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          1556.290000
#
#                                               (within_days_365, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              76
#
#                                               (within_days_365, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7.600000
#
#                                               (within_days_365, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              36
#
#                                               (within_days_365, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         3.600000
#
#                                               (within_days_365, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              22
#
#                                               (within_days_365, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         2.200000
#
#                                               (within_days_365, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                7
#
#                                               (within_days_365, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          0.700000
#
#                                               (within_days_365, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               21
#
#                                               (within_days_365, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2.100000
#
#                                               (within_days_9999, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               136
#
#                                               (within_days_9999, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          13.600000
#
#                                               (within_days_9999, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                   6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                 154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                 109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                  69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                  10
#
#                                               (within_days_9999, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            15562.900
#
#                                               (within_days_9999, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           1556.290000
#
#                                               (within_days_9999, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               76
#
#                                               (within_days_9999, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          7.600000
#
#                                               (within_days_9999, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               36
#
#                                               (within_days_9999, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          3.600000
#
#                                               (within_days_9999, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               22
#
#                                               (within_days_9999, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2.200000
#
#                                               (within_days_9999, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 7
#
#                                               (within_days_9999, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                           0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           0.700000
#
#                                               (within_days_9999, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                21
#
#                                               (within_days_9999, num_100, mean)
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           2.100000

# %% [markdown]
# Finally, we'll join in our Transaction features:

# %%
# Joining feature DF's
df_fa = df_fa.join(transactions_features, how='inner')

print('%d Entries in the DF: ' %(len(df_fa)))
print('%d Features' %(len(df_fa.columns)))
df_fa.head()
# Out:
# 88544 Entries in the DF:
# 143 Features
#                                               city  bd gender  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0    NaN              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0    NaN              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0    NaN              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0    NaN              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0    NaN              13
#
#                                               registration_init_time  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004
#
#                                               is_churn  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=         0
#
#                                              (date_features, date, max_date)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      2017-02-24
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2017-02-27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2017-02-26
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      2017-02-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      2016-10-26
#
#                                              (date_features, date, min_date)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      2017-01-20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2016-09-07
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2016-09-02
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      2016-10-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      2016-10-04
#
#                                               (date_features, date, listening_tenure)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                       35
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                      173
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                      177
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                      123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                       22
#
#                                               (within_days_1, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              1
#
#                                               (within_days_1, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               1
#
#                                               (within_days_1, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                1
#
#                                               (within_days_1, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                           271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           156.204
#
#                                               (within_days_1, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            156.204
#
#                                               (within_days_1, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             0
#
#                                               (within_days_1, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             0
#
#                                               (within_days_1, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             1
#
#                                               (within_days_1, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              1
#
#                                               (within_days_1, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_1, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_1, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_7, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            228
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            243
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            121
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             14
#
#                                               (within_days_7, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       32.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       34.714286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       24.200000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.000000
#
#                                               (within_days_7, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                2
#
#                                               (within_days_7, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         32731.138
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         60581.740
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         30054.147
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2399.824
#
#                                               (within_days_7, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4675.876857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        8654.534286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        6010.829400
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1199.912000
#
#                                               (within_days_7, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           140
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            29
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             4
#
#                                               (within_days_7, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      20.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.428571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       5.800000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.000000
#
#                                               (within_days_7, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             5
#
#                                               (within_days_7, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       4.142857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       2.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.500000
#
#                                               (within_days_7, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             4
#
#                                               (within_days_7, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       2.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       2.000000
#
#                                               (within_days_7, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              0
#
#                                               (within_days_7, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.400000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0.000000
#
#                                               (within_days_7, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             95
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            238
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              5
#
#                                               (within_days_7, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       13.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       24.600000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.500000
#
#                                               (within_days_14, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             512
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             489
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             192
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              17
#
#                                               (within_days_14, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        36.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        34.928571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.454545
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         4.250000
#
#                                               (within_days_14, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 4
#
#                                               (within_days_14, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          98422.408
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         122772.792
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          43518.795
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           2630.818
#
#                                               (within_days_14, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         7030.172000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         8769.485143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         3956.254091
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          657.704500
#
#                                               (within_days_14, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            301
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             44
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              5
#
#                                               (within_days_14, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       21.500000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        4.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.250000
#
#                                               (within_days_14, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             71
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              7
#
#                                               (within_days_14, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        5.071429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.750000
#
#                                               (within_days_14, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             34
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              5
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              4
#
#                                               (within_days_14, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.428571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.357143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1.000000
#
#                                               (within_days_14, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              42
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               0
#
#                                               (within_days_14, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         3.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.785714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.000000
#
#                                               (within_days_14, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             305
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             476
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             174
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               5
#
#                                               (within_days_14, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        21.785714
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        15.818182
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1.250000
#
#                                               (within_days_31, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            1044
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             899
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             457
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             136
#
#                                               (within_days_31, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         6.750000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        36.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        32.107143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        13.600000
#
#                                               (within_days_31, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                28
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                26
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                10
#
#                                               (within_days_31, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           3158.450
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         178909.861
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         231622.820
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         111841.140
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          15562.900
#
#                                               (within_days_31, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          789.612500
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         6169.305552
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         8272.243571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         4301.582308
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1556.290000
#
#                                               (within_days_31, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             33
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            656
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             73
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             80
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             76
#
#                                               (within_days_31, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        8.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       22.620690
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.607143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        3.076923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.600000
#
#                                               (within_days_31, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            135
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             23
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             36
#
#                                               (within_days_31, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4.655172
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.250000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.884615
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        3.600000
#
#                                               (within_days_31, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             61
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             22
#
#                                               (within_days_31, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.103448
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.392857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.200000
#
#                                               (within_days_31, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              74
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               7
#
#                                               (within_days_31, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         2.551724
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.500000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.700000
#
#                                               (within_days_31, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             893
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             456
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              21
#
#                                               (within_days_31, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         2.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        19.689655
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        31.892857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17.538462
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         2.100000
#
#                                               (within_days_90, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            4298
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2396
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            1229
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             136
#
#                                               (within_days_90, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        58.876712
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        35.235294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        21.189655
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        13.600000
#
#                                               (within_days_90, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                73
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                68
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                58
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                10
#
#                                               (within_days_90, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         632743.845
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         770040.608
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         287422.839
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          15562.900
#
#                                               (within_days_90, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         8667.723904
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        11324.126588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         4955.566190
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1556.290000
#
#                                               (within_days_90, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2717
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            203
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             76
#
#                                               (within_days_90, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       37.219178
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2.647059
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        3.500000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7.600000
#
#                                               (within_days_90, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            393
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             81
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             36
#
#                                               (within_days_90, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        5.383562
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1.396552
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        3.600000
#
#                                               (within_days_90, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            188
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             55
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             22
#
#                                               (within_days_90, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        2.575342
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0.948276
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        2.200000
#
#                                               (within_days_90, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             189
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              33
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              60
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               7
#
#                                               (within_days_90, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         2.589041
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0.485294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         1.034483
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0.700000
#
#                                               (within_days_90, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2953
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            1145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              21
#
#                                               (within_days_90, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        28.684932
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        43.426471
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        19.741379
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         2.100000
#
#                                               (within_days_180, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              136
#
#                                               (within_days_180, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         13.600000
#
#                                               (within_days_180, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                  6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                 69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 10
#
#                                               (within_days_180, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           15562.900
#
#                                               (within_days_180, total_secs, mean)  \
# msno
# ...
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2.100000
#
#                                               (within_days_9999, num_unq, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               136
#
#                                               (within_days_9999, num_unq, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          13.600000
#
#                                               (within_days_9999, num_unq, count)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                   6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                 154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                 109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                  69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                  10
#
#                                               (within_days_9999, total_secs, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            15562.900
#
#                                               (within_days_9999, total_secs, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           1556.290000
#
#                                               (within_days_9999, num_25, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                               41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               76
#
#                                               (within_days_9999, num_25, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          7.600000
#
#                                               (within_days_9999, num_50, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               36
#
#                                               (within_days_9999, num_50, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          3.600000
#
#                                               (within_days_9999, num_75, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                               58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               22
#
#                                               (within_days_9999, num_75, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2.200000
#
#                                               (within_days_9999, num_985, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                               323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 7
#
#                                               (within_days_9999, num_985, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                           0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           0.700000
#
#                                               (within_days_9999, num_100, sum)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                21
#
#                                               (within_days_9999, num_100, mean)  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           2.100000
#
#                                               total_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=               60
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=              180
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=              180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=              150
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=              150
#
#                                               total_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                258
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                774
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                774
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                596
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                645
#
#                                               amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=             4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=             4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=             4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=             3.973333
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=             4.300000
#
#                                               diff_renewal_duration  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      0
#
#                                               diff_plan_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            0.0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            0.0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            0.0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            0.0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            0.0
#
#                                               latest_payment_method_id  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        30
#
#                                               latest_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                30
#
#                                               latest_plan_list_price  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     129
#
#                                               latest_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 129
#
#                                               latest_auto_renew  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1
#
#                                               latest_transaction_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 20170220
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 20170207
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 20170202
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 20170228
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 20170204
#
#                                               latest_expire_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=            20170319
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=            20170306
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=            20170301
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=            20170327
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=            20170303
#
#                                               latest_is_cancel  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 0
#
#                                               latest_amount_paid_per_day
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4.966667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    4.300000

# %% [markdown]
# ##  Data Manipulation
# Having joined all the features into a single file, we will now perform some data manipulation tasks to prepare the table for predictive modeling.
#
# First, we will fix the column headers:

# %%
#Fix column headers
df_fa.columns = df_fa.columns.map(''.join)
df_fa.head()
# Out:
#                                               city  bd gender  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0    NaN              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0    NaN              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0    NaN              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0    NaN              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0    NaN              13
#
#                                               registration_init_time  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004
#
#                                               is_churn  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=         0
#
#                                              date_featuresdatemax_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                2017-02-24
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                2017-02-27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                2017-02-26
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                2017-02-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                2016-10-26
#
#                                              date_featuresdatemin_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                2017-01-20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                2016-09-07
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                2016-09-02
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                2016-10-28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                2016-10-04
#
#                                               date_featuresdatelistening_tenure  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 35
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                173
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                177
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 22
#
#                                               within_days_1num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1
#
#                                               within_days_1num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          1
#
#                                               within_days_1total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     156.204
#
#                                               within_days_1total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      156.204
#
#                                               within_days_1num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       1
#
#                                               within_days_1num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_1num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_7num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      228
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      243
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      121
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       14
#
#                                               within_days_7num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 32.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.714286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.200000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.000000
#
#                                               within_days_7num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2
#
#                                               within_days_7total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   32731.138
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   60581.740
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   30054.147
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2399.824
#
#                                               within_days_7total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4675.876857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  8654.534286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  6010.829400
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1199.912000
#
#                                               within_days_7num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     140
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      29
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.428571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 5.800000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       5
#
#                                               within_days_7num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 4.142857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 2.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.500000
#
#                                               within_days_7num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 2.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_7num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.400000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  0.000000
#
#                                               within_days_7num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       95
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      238
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_7num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 13.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.600000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.500000
#
#                                               within_days_14num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       512
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       489
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       192
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        17
#
#                                               within_days_14num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.928571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.454545
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   4.250000
#
#                                               within_days_14num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           4
#
#                                               within_days_14total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    98422.408
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   122772.792
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    43518.795
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2630.818
#
#                                               within_days_14total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   7030.172000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8769.485143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3956.254091
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    657.704500
#
#                                               within_days_14num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      301
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       44
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_14num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 21.500000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  4.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.250000
#
#                                               within_days_14num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       71
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7
#
#                                               within_days_14num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.071429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.750000
#
#                                               within_days_14num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       34
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        5
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        4
#
#                                               within_days_14num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.428571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.357143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.000000
#
#                                               within_days_14num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        42
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_14num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   3.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.785714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.000000
#
#                                               within_days_14num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       305
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       476
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       174
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         5
#
#                                               within_days_14num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  21.785714
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  15.818182
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1.250000
#
#                                               within_days_31num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      1044
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       899
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       457
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_31num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.750000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  32.107143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_31num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          28
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          26
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_31total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3158.450
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   178909.861
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   231622.820
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   111841.140
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_31total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    789.612500
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   6169.305552
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8272.243571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4301.582308
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_31num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       33
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      656
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       73
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       80
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_31num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  8.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 22.620690
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.607143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.076923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_31num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      135
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       23
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_31num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4.655172
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.250000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.884615
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_31num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       61
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_31num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.103448
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.392857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_31num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        74
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_31num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.551724
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.500000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_31num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       893
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       456
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_31num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   2.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  19.689655
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  31.892857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.538462
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_90num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      4298
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2396
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1229
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_90num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  58.876712
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  35.235294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  21.189655
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_90num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          73
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          68
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          58
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_90total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   632743.845
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   770040.608
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   287422.839
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_90total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   8667.723904
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  11324.126588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4955.566190
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_90num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2717
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      203
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_90num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 37.219178
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.647059
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.500000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_90num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      393
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       81
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_90num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.383562
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.396552
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_90num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      188
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       55
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_90num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.575342
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.948276
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_90num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       189
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        33
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        60
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_90num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.589041
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.485294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.034483
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_90num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2953
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_90num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  28.684932
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  43.426471
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  19.741379
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_180num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        136
#
#                                               within_days_180num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   13.600000
#
#                                               within_days_180num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           10
#
#                                               within_days_180total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     15562.900
#
#                                               within_days_180total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    1556.290000
#
#                                               within_days_180num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        76
#
#                                               within_days_180num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   7.600000
#
#                                               within_days_180num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        36
#
#                                               within_days_180num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   3.600000
#
#                                               within_days_180num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        22
#
#                                               within_days_180num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.200000
#
# ...
#
#                                               within_days_365num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         21
#
#                                               within_days_365num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2.100000
#
#                                               within_days_9999num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         136
#
#                                               within_days_9999num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    13.600000
#
#                                               within_days_9999num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                           154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                           109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            10
#
#                                               within_days_9999total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      15562.900
#
#                                               within_days_9999total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     1556.290000
#
#                                               within_days_9999num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         76
#
#                                               within_days_9999num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    7.600000
#
#                                               within_days_9999num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         36
#
#                                               within_days_9999num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    3.600000
#
#                                               within_days_9999num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         22
#
#                                               within_days_9999num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2.200000
#
#                                               within_days_9999num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           7
#
#                                               within_days_9999num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     0.700000
#
#                                               within_days_9999num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          21
#
#                                               within_days_9999num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2.100000
#
#                                               total_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=               60
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=              180
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=              180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=              150
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=              150
#
#                                               total_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                258
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                774
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                774
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                596
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                645
#
#                                               amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=             4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=             4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=             4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=             3.973333
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=             4.300000
#
#                                               diff_renewal_duration  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      0
#
#                                               diff_plan_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            0.0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            0.0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            0.0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            0.0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            0.0
#
#                                               latest_payment_method_id  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        30
#
#                                               latest_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                30
#
#                                               latest_plan_list_price  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     129
#
#                                               latest_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 129
#
#                                               latest_auto_renew  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1
#
#                                               latest_transaction_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 20170220
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 20170207
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 20170202
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 20170228
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 20170204
#
#                                               latest_expire_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=            20170319
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=            20170306
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=            20170301
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=            20170327
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=            20170303
#
#                                               latest_is_cancel  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 0
#
#                                               latest_amount_paid_per_day
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4.966667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    4.300000

# %% [markdown]
# Next, we will change infinite and 'na' values to -9999, wildly different than other values in the range, so that our algorithms see them as 'different'.

# %%
#Handle bad values
df_fa['amount_paid_per_day'].replace([np.inf, -np.inf], -9999, inplace=True)
df_fa['latest_amount_paid_per_day'].replace([np.inf, -np.inf], -9999, inplace=True)
df_fa['diff_plan_amount_paid_per_day'].replace([np.inf, -np.inf], -9999, inplace=True)
df_fa['diff_plan_amount_paid_per_day'].fillna(-9999, inplace=True)
df_fa.isnull().any()
# Out:
# city                                 False
# bd                                   False
# gender                                True
# registered_via                       False
# registration_init_time               False
# is_churn                             False
# date_featuresdatemax_date            False
# date_featuresdatemin_date            False
# date_featuresdatelistening_tenure    False
# within_days_1num_unqsum              False
# within_days_1num_unqmean             False
# within_days_1num_unqcount            False
# within_days_1total_secssum           False
# within_days_1total_secsmean          False
# within_days_1num_25sum               False
# within_days_1num_25mean              False
# within_days_1num_50sum               False
# within_days_1num_50mean              False
# within_days_1num_75sum               False
# within_days_1num_75mean              False
# within_days_1num_985sum              False
# within_days_1num_985mean             False
# within_days_1num_100sum              False
# within_days_1num_100mean             False
# within_days_7num_unqsum              False
# within_days_7num_unqmean             False
# within_days_7num_unqcount            False
# within_days_7total_secssum           False
# within_days_7total_secsmean          False
# within_days_7num_25sum               False
# within_days_7num_25mean              False
# within_days_7num_50sum               False
# within_days_7num_50mean              False
# within_days_7num_75sum               False
# within_days_7num_75mean              False
# within_days_7num_985sum              False
# within_days_7num_985mean             False
# within_days_7num_100sum              False
# within_days_7num_100mean             False
# within_days_14num_unqsum             False
# within_days_14num_unqmean            False
# within_days_14num_unqcount           False
# within_days_14total_secssum          False
# within_days_14total_secsmean         False
# within_days_14num_25sum              False
# within_days_14num_25mean             False
# within_days_14num_50sum              False
# within_days_14num_50mean             False
# within_days_14num_75sum              False
# within_days_14num_75mean             False
# within_days_14num_985sum             False
# within_days_14num_985mean            False
# within_days_14num_100sum             False
# within_days_14num_100mean            False
# within_days_31num_unqsum             False
# within_days_31num_unqmean            False
# within_days_31num_unqcount           False
# within_days_31total_secssum          False
# within_days_31total_secsmean         False
# within_days_31num_25sum              False
# within_days_31num_25mean             False
# within_days_31num_50sum              False
# within_days_31num_50mean             False
# within_days_31num_75sum              False
# within_days_31num_75mean             False
# within_days_31num_985sum             False
# within_days_31num_985mean            False
# within_days_31num_100sum             False
# within_days_31num_100mean            False
# within_days_90num_unqsum             False
# within_days_90num_unqmean            False
# within_days_90num_unqcount           False
# within_days_90total_secssum          False
# within_days_90total_secsmean         False
# within_days_90num_25sum              False
# within_days_90num_25mean             False
# within_days_90num_50sum              False
# within_days_90num_50mean             False
# within_days_90num_75sum              False
# within_days_90num_75mean             False
# within_days_90num_985sum             False
# within_days_90num_985mean            False
# within_days_90num_100sum             False
# within_days_90num_100mean            False
# within_days_180num_unqsum            False
# within_days_180num_unqmean           False
# within_days_180num_unqcount          False
# within_days_180total_secssum         False
# within_days_180total_secsmean        False
# within_days_180num_25sum             False
# within_days_180num_25mean            False
# within_days_180num_50sum             False
# within_days_180num_50mean            False
# within_days_180num_75sum             False
# within_days_180num_75mean            False
# within_days_180num_985sum            False
# within_days_180num_985mean           False
# within_days_180num_100sum            False
# within_days_180num_100mean           False
# within_days_365num_unqsum            False
# within_days_365num_unqmean           False
# within_days_365num_unqcount          False
# within_days_365total_secssum         False
# within_days_365total_secsmean        False
# within_days_365num_25sum             False
# within_days_365num_25mean            False
# within_days_365num_50sum             False
# within_days_365num_50mean            False
# within_days_365num_75sum             False
# within_days_365num_75mean            False
# within_days_365num_985sum            False
# within_days_365num_985mean           False
# within_days_365num_100sum            False
# within_days_365num_100mean           False
# within_days_9999num_unqsum           False
# within_days_9999num_unqmean          False
# within_days_9999num_unqcount         False
# within_days_9999total_secssum        False
# within_days_9999total_secsmean       False
# within_days_9999num_25sum            False
# within_days_9999num_25mean           False
# within_days_9999num_50sum            False
# within_days_9999num_50mean           False
# within_days_9999num_75sum            False
# within_days_9999num_75mean           False
# within_days_9999num_985sum           False
# within_days_9999num_985mean          False
# within_days_9999num_100sum           False
# within_days_9999num_100mean          False
# total_plan_days                      False
# total_amount_paid                    False
# amount_paid_per_day                  False
# diff_renewal_duration                False
# diff_plan_amount_paid_per_day        False
# latest_payment_method_id             False
# latest_plan_days                     False
# latest_plan_list_price               False
# latest_amount_paid                   False
# latest_auto_renew                    False
# latest_transaction_date              False
# latest_expire_date                   False
# latest_is_cancel                     False
# latest_amount_paid_per_day           False
# dtype: bool

# %% [markdown]
# The cell above uploads verifies we have no null values in our data.
#
# Now let's inspect our data types:

# %%
df_fa.dtypes
# Out:
# city                                          int64
# bd                                            int64
# gender                                       object
# registered_via                                int64
# registration_init_time                        int64
# is_churn                                      int64
# date_featuresdatemax_date            datetime64[ns]
# date_featuresdatemin_date            datetime64[ns]
# date_featuresdatelistening_tenure             int64
# within_days_1num_unqsum                       int64
# within_days_1num_unqmean                      int64
# within_days_1num_unqcount                     int64
# within_days_1total_secssum                  float64
# within_days_1total_secsmean                 float64
# within_days_1num_25sum                        int64
# within_days_1num_25mean                       int64
# within_days_1num_50sum                        int64
# within_days_1num_50mean                       int64
# within_days_1num_75sum                        int64
# within_days_1num_75mean                       int64
# within_days_1num_985sum                       int64
# within_days_1num_985mean                      int64
# within_days_1num_100sum                       int64
# within_days_1num_100mean                      int64
# within_days_7num_unqsum                       int64
# within_days_7num_unqmean                    float64
# within_days_7num_unqcount                     int64
# within_days_7total_secssum                  float64
# within_days_7total_secsmean                 float64
# within_days_7num_25sum                        int64
# within_days_7num_25mean                     float64
# within_days_7num_50sum                        int64
# within_days_7num_50mean                     float64
# within_days_7num_75sum                        int64
# within_days_7num_75mean                     float64
# within_days_7num_985sum                       int64
# within_days_7num_985mean                    float64
# within_days_7num_100sum                       int64
# within_days_7num_100mean                    float64
# within_days_14num_unqsum                      int64
# within_days_14num_unqmean                   float64
# within_days_14num_unqcount                    int64
# within_days_14total_secssum                 float64
# within_days_14total_secsmean                float64
# within_days_14num_25sum                       int64
# within_days_14num_25mean                    float64
# within_days_14num_50sum                       int64
# within_days_14num_50mean                    float64
# within_days_14num_75sum                       int64
# within_days_14num_75mean                    float64
# within_days_14num_985sum                      int64
# within_days_14num_985mean                   float64
# within_days_14num_100sum                      int64
# within_days_14num_100mean                   float64
# within_days_31num_unqsum                      int64
# within_days_31num_unqmean                   float64
# within_days_31num_unqcount                    int64
# within_days_31total_secssum                 float64
# within_days_31total_secsmean                float64
# within_days_31num_25sum                       int64
# within_days_31num_25mean                    float64
# within_days_31num_50sum                       int64
# within_days_31num_50mean                    float64
# within_days_31num_75sum                       int64
# within_days_31num_75mean                    float64
# within_days_31num_985sum                      int64
# within_days_31num_985mean                   float64
# within_days_31num_100sum                      int64
# within_days_31num_100mean                   float64
# within_days_90num_unqsum                      int64
# within_days_90num_unqmean                   float64
# within_days_90num_unqcount                    int64
# within_days_90total_secssum                 float64
# within_days_90total_secsmean                float64
# within_days_90num_25sum                       int64
# within_days_90num_25mean                    float64
# within_days_90num_50sum                       int64
# within_days_90num_50mean                    float64
# within_days_90num_75sum                       int64
# within_days_90num_75mean                    float64
# within_days_90num_985sum                      int64
# within_days_90num_985mean                   float64
# within_days_90num_100sum                      int64
# within_days_90num_100mean                   float64
# within_days_180num_unqsum                     int64
# within_days_180num_unqmean                  float64
# within_days_180num_unqcount                   int64
# within_days_180total_secssum                float64
# within_days_180total_secsmean               float64
# within_days_180num_25sum                      int64
# within_days_180num_25mean                   float64
# within_days_180num_50sum                      int64
# within_days_180num_50mean                   float64
# within_days_180num_75sum                      int64
# within_days_180num_75mean                   float64
# within_days_180num_985sum                     int64
# within_days_180num_985mean                  float64
# within_days_180num_100sum                     int64
# within_days_180num_100mean                  float64
# within_days_365num_unqsum                     int64
# within_days_365num_unqmean                  float64
# within_days_365num_unqcount                   int64
# within_days_365total_secssum                float64
# within_days_365total_secsmean               float64
# within_days_365num_25sum                      int64
# within_days_365num_25mean                   float64
# within_days_365num_50sum                      int64
# within_days_365num_50mean                   float64
# within_days_365num_75sum                      int64
# within_days_365num_75mean                   float64
# within_days_365num_985sum                     int64
# within_days_365num_985mean                  float64
# within_days_365num_100sum                     int64
# within_days_365num_100mean                  float64
# within_days_9999num_unqsum                    int64
# within_days_9999num_unqmean                 float64
# within_days_9999num_unqcount                  int64
# within_days_9999total_secssum               float64
# within_days_9999total_secsmean              float64
# within_days_9999num_25sum                     int64
# within_days_9999num_25mean                  float64
# within_days_9999num_50sum                     int64
# within_days_9999num_50mean                  float64
# within_days_9999num_75sum                     int64
# within_days_9999num_75mean                  float64
# within_days_9999num_985sum                    int64
# within_days_9999num_985mean                 float64
# within_days_9999num_100sum                    int64
# within_days_9999num_100mean                 float64
# total_plan_days                               int64
# total_amount_paid                             int64
# amount_paid_per_day                         float64
# diff_renewal_duration                         int64
# diff_plan_amount_paid_per_day               float64
# latest_payment_method_id                      int64
# latest_plan_days                              int64
# latest_plan_list_price                        int64
# latest_amount_paid                            int64
# latest_auto_renew                             int64
# latest_transaction_date                       int64
# latest_expire_date                            int64
# latest_is_cancel                              int64
# latest_amount_paid_per_day                  float64
# dtype: object

# %% [markdown]
# We see we have a couple datetime objects in the file.  We'll need to address these, as the ML algorithms don't like them.  The code below breaks datetime formatted columns up into 4 separate columns.

# %%
def split_date_col(date_col_name):
    """Function that takes a column of datetime64[ns] items and converts it into 4 columns:
        1) Year integer
        2) Month integer
        3) Day integer
        4) Days since January 1, 2001, as an integer
        
        It then deletes the original date 
        
    Args:
        date_col_name (string):  The column name, as a string.
    """
    df_fa[date_col_name + '_year'] = df_fa[date_col_name].dt.year
    df_fa[date_col_name + '_month'] = df_fa[date_col_name].dt.month
    df_fa[date_col_name + '_day'] = df_fa[date_col_name].dt.day
    df_fa[date_col_name + '_absday'] = ((df_fa[date_col_name] - pd.to_datetime('1/1/2000'))
                                      .astype('timedelta64[D]')
                                      .astype('int64')
                                     )
    df_fa.drop(date_col_name, axis=1, inplace=True)

# %%
#Only run this cell once, else it will fail on the date columns it deletes
split_date_col('date_featuresdatemax_date')
split_date_col('date_featuresdatemin_date')

# %% [markdown]
# Now let's re-check our cells:

# %%
df_fa.dtypes
# Out:
# city                                   int64
# bd                                     int64
# gender                                object
# registered_via                         int64
# registration_init_time                 int64
# is_churn                               int64
# date_featuresdatelistening_tenure      int64
# within_days_1num_unqsum                int64
# within_days_1num_unqmean               int64
# within_days_1num_unqcount              int64
# within_days_1total_secssum           float64
# within_days_1total_secsmean          float64
# within_days_1num_25sum                 int64
# within_days_1num_25mean                int64
# within_days_1num_50sum                 int64
# within_days_1num_50mean                int64
# within_days_1num_75sum                 int64
# within_days_1num_75mean                int64
# within_days_1num_985sum                int64
# within_days_1num_985mean               int64
# within_days_1num_100sum                int64
# within_days_1num_100mean               int64
# within_days_7num_unqsum                int64
# within_days_7num_unqmean             float64
# within_days_7num_unqcount              int64
# within_days_7total_secssum           float64
# within_days_7total_secsmean          float64
# within_days_7num_25sum                 int64
# within_days_7num_25mean              float64
# within_days_7num_50sum                 int64
# within_days_7num_50mean              float64
# within_days_7num_75sum                 int64
# within_days_7num_75mean              float64
# within_days_7num_985sum                int64
# within_days_7num_985mean             float64
# within_days_7num_100sum                int64
# within_days_7num_100mean             float64
# within_days_14num_unqsum               int64
# within_days_14num_unqmean            float64
# within_days_14num_unqcount             int64
# within_days_14total_secssum          float64
# within_days_14total_secsmean         float64
# within_days_14num_25sum                int64
# within_days_14num_25mean             float64
# within_days_14num_50sum                int64
# within_days_14num_50mean             float64
# within_days_14num_75sum                int64
# within_days_14num_75mean             float64
# within_days_14num_985sum               int64
# within_days_14num_985mean            float64
# within_days_14num_100sum               int64
# within_days_14num_100mean            float64
# within_days_31num_unqsum               int64
# within_days_31num_unqmean            float64
# within_days_31num_unqcount             int64
# within_days_31total_secssum          float64
# within_days_31total_secsmean         float64
# within_days_31num_25sum                int64
# within_days_31num_25mean             float64
# within_days_31num_50sum                int64
# within_days_31num_50mean             float64
# within_days_31num_75sum                int64
# within_days_31num_75mean             float64
# within_days_31num_985sum               int64
# within_days_31num_985mean            float64
# within_days_31num_100sum               int64
# within_days_31num_100mean            float64
# within_days_90num_unqsum               int64
# within_days_90num_unqmean            float64
# within_days_90num_unqcount             int64
# within_days_90total_secssum          float64
# within_days_90total_secsmean         float64
# within_days_90num_25sum                int64
# within_days_90num_25mean             float64
# within_days_90num_50sum                int64
# within_days_90num_50mean             float64
# within_days_90num_75sum                int64
# within_days_90num_75mean             float64
# within_days_90num_985sum               int64
# within_days_90num_985mean            float64
# within_days_90num_100sum               int64
# within_days_90num_100mean            float64
# within_days_180num_unqsum              int64
# within_days_180num_unqmean           float64
# within_days_180num_unqcount            int64
# within_days_180total_secssum         float64
# within_days_180total_secsmean        float64
# within_days_180num_25sum               int64
# within_days_180num_25mean            float64
# within_days_180num_50sum               int64
# within_days_180num_50mean            float64
# within_days_180num_75sum               int64
# within_days_180num_75mean            float64
# within_days_180num_985sum              int64
# within_days_180num_985mean           float64
# within_days_180num_100sum              int64
# within_days_180num_100mean           float64
# within_days_365num_unqsum              int64
# within_days_365num_unqmean           float64
# within_days_365num_unqcount            int64
# within_days_365total_secssum         float64
# within_days_365total_secsmean        float64
# within_days_365num_25sum               int64
# within_days_365num_25mean            float64
# within_days_365num_50sum               int64
# within_days_365num_50mean            float64
# within_days_365num_75sum               int64
# within_days_365num_75mean            float64
# within_days_365num_985sum              int64
# within_days_365num_985mean           float64
# within_days_365num_100sum              int64
# within_days_365num_100mean           float64
# within_days_9999num_unqsum             int64
# within_days_9999num_unqmean          float64
# within_days_9999num_unqcount           int64
# within_days_9999total_secssum        float64
# within_days_9999total_secsmean       float64
# within_days_9999num_25sum              int64
# within_days_9999num_25mean           float64
# within_days_9999num_50sum              int64
# within_days_9999num_50mean           float64
# within_days_9999num_75sum              int64
# within_days_9999num_75mean           float64
# within_days_9999num_985sum             int64
# within_days_9999num_985mean          float64
# within_days_9999num_100sum             int64
# within_days_9999num_100mean          float64
# total_plan_days                        int64
# total_amount_paid                      int64
# amount_paid_per_day                  float64
# diff_renewal_duration                  int64
# diff_plan_amount_paid_per_day        float64
# latest_payment_method_id               int64
# latest_plan_days                       int64
# latest_plan_list_price                 int64
# latest_amount_paid                     int64
# latest_auto_renew                      int64
# latest_transaction_date                int64
# latest_expire_date                     int64
# latest_is_cancel                       int64
# latest_amount_paid_per_day           float64
# date_featuresdatemax_date_year         int64
# date_featuresdatemax_date_month        int64
# date_featuresdatemax_date_day          int64
# date_featuresdatemax_date_absday       int64
# date_featuresdatemin_date_year         int64
# date_featuresdatemin_date_month        int64
# date_featuresdatemin_date_day          int64
# date_featuresdatemin_date_absday       int64
# dtype: object

# %%
df_fa.describe(include='all')
# Out:
#                 city            bd gender  registered_via  \
# count   88544.000000  88544.000000  45906    88544.000000
# unique           NaN           NaN      2             NaN
# top              NaN           NaN   male             NaN
# freq             NaN           NaN  24390             NaN
# mean        6.525038     14.980733    NaN        6.635018
# std         6.551445     18.431336    NaN        2.234529
# min         1.000000    -49.000000    NaN        3.000000
# 25%         1.000000      0.000000    NaN        4.000000
# 50%         4.000000     17.000000    NaN        7.000000
# 75%        13.000000     27.000000    NaN        9.000000
# max        22.000000   1051.000000    NaN       13.000000
#
#         registration_init_time      is_churn  \
# count             8.854400e+04  88544.000000
# unique                     NaN           NaN
# top                        NaN           NaN
# freq                       NaN           NaN
# mean              2.013375e+07      0.505590
# std               2.896439e+04      0.499972
# min               2.004033e+07      0.000000
# 25%               2.012053e+07      0.000000
# 50%               2.014073e+07      1.000000
# 75%               2.016012e+07      1.000000
# max               2.017023e+07      1.000000
#
#         date_featuresdatelistening_tenure  within_days_1num_unqsum  \
# count                        88544.000000             88544.000000
# unique                                NaN                      NaN
# top                                   NaN                      NaN
# freq                                  NaN                      NaN
# mean                           489.896266                20.698794
# std                            271.954761                26.816538
# min                              0.000000                 1.000000
# 25%                            248.000000                 4.000000
# 50%                            509.000000                11.000000
# 75%                            776.000000                27.000000
# max                            789.000000               661.000000
#
#         within_days_1num_unqmean  within_days_1num_unqcount  \
# count               88544.000000                    88544.0
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                   20.698794                        1.0
# std                    26.816538                        0.0
# min                     1.000000                        1.0
# 25%                     4.000000                        1.0
# 50%                    11.000000                        1.0
# 75%                    27.000000                        1.0
# max                   661.000000                        1.0
#
#         within_days_1total_secssum  within_days_1total_secsmean  \
# count                 88544.000000                 88544.000000
# unique                         NaN                          NaN
# top                            NaN                          NaN
# freq                           NaN                          NaN
# mean                   5292.578450                  5292.578450
# std                    7839.883628                  7839.883628
# min                       0.030000                     0.030000
# 25%                     821.058500                   821.058500
# 50%                    2595.075000                  2595.075000
# 75%                    6509.136500                  6509.136500
# max                  437603.468000                437603.468000
#
#         within_days_1num_25sum  within_days_1num_25mean  \
# count             88544.000000             88544.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                  4.751005                 4.751005
# std                  11.209580                11.209580
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   1.000000                 1.000000
# 75%                   5.000000                 5.000000
# max                 570.000000               570.000000
#
#         within_days_1num_50sum  within_days_1num_50mean  \
# count             88544.000000             88544.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                  1.181175                 1.181175
# std                   3.122491                 3.122491
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   1.000000                 1.000000
# max                 195.000000               195.000000
#
#         within_days_1num_75sum  within_days_1num_75mean  \
# count             88544.000000             88544.000000
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                  0.712719                 0.712719
# std                   1.569186                 1.569186
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   1.000000                 1.000000
# max                  71.000000                71.000000
#
#         within_days_1num_985sum  within_days_1num_985mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                   0.790985                  0.790985
# std                    2.056548                  2.056548
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    1.000000                  1.000000
# max                  224.000000                224.000000
#
#         within_days_1num_100sum  within_days_1num_100mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                  20.047660                 20.047660
# std                   31.926074                 31.926074
# min                    0.000000                  0.000000
# 25%                    2.000000                  2.000000
# 50%                    9.000000                  9.000000
# 75%                   24.000000                 24.000000
# max                 1859.000000               1859.000000
#
#         within_days_7num_unqsum  within_days_7num_unqmean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                  94.714458                 21.900082
# std                  123.736267                 22.179267
# min                    1.000000                  1.000000
# 25%                   17.000000                  7.571429
# 50%                   53.000000                 16.000000
# 75%                  124.000000                 28.666667
# max                 2992.000000                748.000000
#
#         within_days_7num_unqcount  within_days_7total_secssum  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                     3.630568                25398.043300
# std                      2.019227                37825.652389
# min                      1.000000                    0.078000
# 25%                      2.000000                 3718.143000
# 50%                      3.000000                12904.532500
# 75%                      5.000000                31483.468500
# max                      7.000000               604487.476000
#
#         within_days_7total_secsmean  within_days_7num_25sum  \
# count                  88544.000000            88544.000000
# unique                          NaN                     NaN
# top                             NaN                     NaN
# freq                            NaN                     NaN
# mean                    5679.751873               20.606806
# std                     6814.978016               40.174639
# min                        0.078000                0.000000
# 25%                     1705.418000                2.000000
# 50%                     3780.617429                8.000000
# 75%                     7136.028982               24.000000
# max                   437603.468000             3957.000000
#
#         within_days_7num_25mean  within_days_7num_50sum  \
# count              88544.000000            88544.000000
# unique                      NaN                     NaN
# top                         NaN                     NaN
# freq                        NaN                     NaN
# mean                   5.048088                5.118721
# std                    9.170749                9.780551
# min                    0.000000                0.000000
# 25%                    1.000000                0.000000
# 50%                    2.600000                2.000000
# 75%                    6.000000                6.000000
# max                  989.250000              354.000000
#
#         within_days_7num_50mean  within_days_7num_75sum  \
# count              88544.000000            88544.000000
# unique                      NaN                     NaN
# top                         NaN                     NaN
# freq                        NaN                     NaN
# mean                   1.264542                3.193474
# std                    2.416056                5.525064
# min                    0.000000                0.000000
# 25%                    0.000000                0.000000
# 50%                    0.666667                1.000000
# 75%                    1.500000                4.000000
# max                  132.500000              369.000000
#
#         within_days_7num_75mean  within_days_7num_985sum  \
# count              88544.000000             88544.000000
# unique                      NaN                      NaN
# top                         NaN                      NaN
# freq                        NaN                      NaN
# mean                   0.764835                 3.609866
# std                    1.240117                 8.967416
# min                    0.000000                 0.000000
# 25%                    0.000000                 0.000000
# 50%                    0.500000                 2.000000
# 75%                    1.000000                 4.000000
# max                   65.500000              1207.000000
#
#         within_days_7num_985mean  within_days_7num_100sum  \
# count               88544.000000             88544.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                    0.839836                96.809236
# std                     1.630039               154.190616
# min                     0.000000                 0.000000
# 25%                     0.000000                12.000000
# 50%                     0.500000                47.000000
# 75%                     1.000000               118.000000
# max                   172.428571              3211.000000
#
#         within_days_7num_100mean  within_days_14num_unqsum  \
# count               88544.000000              88544.000000
# unique                       NaN                       NaN
# top                          NaN                       NaN
# freq                         NaN                       NaN
# mean                   21.497445                180.072506
# std                    27.963725                232.545094
# min                     0.000000                  1.000000
# 25%                     5.666667                 34.000000
# 50%                    13.750000                105.000000
# 75%                    26.833333                236.000000
# max                  1859.000000               5290.000000
#
#         within_days_14num_unqmean  within_days_14num_unqcount  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                    22.383794                    6.679696
# std                     20.836810                    4.052415
# min                      1.000000                    1.000000
# 25%                      9.200000                    3.000000
# 50%                     17.100000                    6.000000
# 75%                     29.000000                   10.000000
# max                    661.000000                   14.000000
#
#         within_days_14total_secssum  within_days_14total_secsmean  \
# count                  8.854400e+04                  88544.000000
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                   4.851858e+04                   5818.581592
# std                    7.152130e+04                   6539.990675
# min                    7.800000e-02                      0.078000
# 25%                    7.838667e+03                   2116.791375
# 50%                    2.553986e+04                   4091.579700
# 75%                    5.991438e+04                   7206.990196
# max                    1.209334e+06                 437603.468000
#
#         within_days_14num_25sum  within_days_14num_25mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                  38.873690                  5.179982
# std                   69.286828                  8.255339
# min                    0.000000                  0.000000
# 25%                    5.000000                  1.250000
# 50%                   17.000000                  3.000000
# 75%                   46.000000                  6.285714
# max                 5381.000000                676.000000
#
#         within_days_14num_50sum  within_days_14num_50mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                   9.669735                  1.298046
# std                   16.423555                  2.159017
# min                    0.000000                  0.000000
# 25%                    1.000000                  0.307692
# 50%                    4.000000                  0.800000
# 75%                   12.000000                  1.571429
# max                  613.000000                132.500000
#
#         within_days_14num_75sum  within_days_14num_75mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                   6.069570                  0.785710
# std                    9.495713                  1.138329
# min                    0.000000                  0.000000
# 25%                    1.000000                  0.166667
# 50%                    3.000000                  0.500000
# 75%                    8.000000                  1.000000
# max                  385.000000                 65.500000
#
#         within_days_14num_985sum  within_days_14num_985mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                    6.831553                   0.857796
# std                    16.007510                   1.546520
# min                     0.000000                   0.000000
# 25%                     1.000000                   0.166667
# 50%                     3.000000                   0.538462
# 75%                     8.000000                   1.000000
# max                  1877.000000                 156.416667
#
#         within_days_14num_100sum  within_days_14num_100mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                  185.109313                  22.017982
# std                   291.280077                  26.898005
# min                     0.000000                   0.000000
# 25%                    27.000000                   7.200000
# 50%                    93.000000                  15.000000
# 75%                   225.000000                  27.090909
# max                  5765.000000                1859.000000
#
#         within_days_31num_unqsum  within_days_31num_unqmean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                  386.728101                  23.271521
# std                   477.079939                  19.372295
# min                     1.000000                   1.000000
# 25%                    84.000000                  11.153846
# 50%                   238.000000                  18.777778
# 75%                   511.000000                  29.545455
# max                 10086.000000                 560.333333
#
#         within_days_31num_unqcount  within_days_31total_secssum  \
# count                 88544.000000                 8.854400e+04
# unique                         NaN                          NaN
# top                            NaN                          NaN
# freq                           NaN                          NaN
# mean                     13.902444                 1.039538e+05
# std                       8.663977                 1.469971e+05
# min                       1.000000                 2.130000e-01
# 25%                       6.000000                 1.964592e+04
# 50%                      13.000000                 5.835679e+04
# 75%                      20.000000                 1.296859e+05
# max                      31.000000                 2.665440e+06
#
#         within_days_31total_secsmean  within_days_31num_25sum  \
# count                   88544.000000             88544.000000
# unique                           NaN                      NaN
# top                              NaN                      NaN
# freq                             NaN                      NaN
# mean                     6040.184570                84.352706
# std                      6020.766839               135.636164
# min                         0.213000                 0.000000
# 25%                      2611.727415                14.000000
# 50%                      4496.575193                42.000000
# 75%                      7375.110225               103.000000
# max                    187136.586000             10384.000000
#
#         within_days_31num_25mean  within_days_31num_50sum  \
# count               88544.000000             88544.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                    5.450459                20.850831
# std                     7.741246                30.899691
# min                     0.000000                 0.000000
# 25%                     1.714286                 3.000000
# 50%                     3.500000                11.000000
# 75%                     6.720556                26.000000
# max                   676.000000              1131.000000
#
#         within_days_31num_50mean  within_days_31num_75sum  \
# count               88544.000000             88544.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                    1.359949                13.151473
# std                     1.919181                18.358084
# min                     0.000000                 0.000000
# 25%                     0.450000                 2.000000
# 50%                     0.928571                 7.000000
# 75%                     1.666667                17.000000
# max                   132.500000               585.000000
#
#         within_days_31num_75mean  within_days_31num_985sum  \
# count               88544.000000              88544.000000
# unique                       NaN                       NaN
# top                          NaN                       NaN
# freq                         NaN                       NaN
# mean                    0.825081                 14.948783
# std                     1.029136                 36.104464
# min                     0.000000                  0.000000
# 25%                     0.294118                  2.000000
# 50%                     0.612903                  8.000000
# 75%                     1.052632                 18.000000
# max                    65.500000               3930.000000
#
#         within_days_31num_985mean  within_days_31num_100sum  \
# count                88544.000000              88544.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                     0.904241                396.595557
# std                      1.563621                600.717536
# min                      0.000000                  0.000000
# 25%                      0.300000                 69.000000
# 50%                      0.636364                214.000000
# 75%                      1.125000                484.000000
# max                    151.826087              13493.000000
#
#         within_days_31num_100mean  within_days_90num_unqsum  \
# count                88544.000000              88544.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                    22.841633               1093.917736
# std                     24.834585               1341.237189
# min                      0.000000                  1.000000
# 25%                      9.000000                233.000000
# 50%                     16.500000                667.000000
# 75%                     27.826087               1464.000000
# max                    810.000000              26703.000000
#
#         within_days_90num_unqmean  within_days_90num_unqcount  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                    24.238664                   37.852435
# std                     18.684102                   25.324540
# min                      1.000000                    1.000000
# 25%                     12.710028                   16.000000
# 50%                     19.993750                   36.000000
# 75%                     30.166667                   56.000000
# max                    560.333333                   90.000000
#
#         within_days_90total_secssum  within_days_90total_secsmean  \
# count                  8.854400e+04                  8.854400e+04
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                  -8.333365e+11                 -1.651270e+10
# std                    2.191767e+14                  3.964256e+12
# min                   -6.456360e+16                 -1.132695e+15
# 25%                    5.537270e+04                  2.998566e+03
# 50%                    1.652595e+05                  4.812825e+03
# 75%                    3.737988e+05                  7.603972e+03
# max                    7.546893e+06                  2.181567e+05
#
#         within_days_90num_25sum  within_days_90num_25mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                 241.791143                  5.797655
# std                  382.272707                  7.515411
# min                    0.000000                  0.000000
# 25%                   42.000000                  2.113636
# 50%                  123.000000                  3.935484
# 75%                  295.000000                  7.100000
# max                35029.000000                676.000000
#
#         within_days_90num_50sum  within_days_90num_50mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                  59.157650                  1.442505
# std                   82.445972                  1.770876
# min                    0.000000                  0.000000
# 25%                   11.000000                  0.565217
# 50%                   33.000000                  1.000000
# 75%                   76.000000                  1.769231
# max                 3017.000000                 88.333333
#
#         within_days_90num_75sum  within_days_90num_75mean  \
# count              88544.000000              88544.000000
# unique                      NaN                       NaN
# top                         NaN                       NaN
# freq                        NaN                       NaN
# mean                  37.497256                  0.874044
# std                   50.426151                  0.969375
# min                    0.000000                  0.000000
# 25%                    7.000000                  0.382353
# 50%                   22.000000                  0.671875
# 75%                   49.000000                  1.098120
# max                 1336.000000                 65.500000
#
#         within_days_90num_985sum  within_days_90num_985mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                   42.036321                   0.943332
# std                    89.884588                   1.397562
# min                     0.000000                   0.000000
# 25%                     7.000000                   0.387097
# 50%                    22.000000                   0.692308
# 75%                    52.000000                   1.166667
# max                 11151.000000                 159.300000
#
#         within_days_90num_100sum  within_days_90num_100mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                 1121.233093                  23.773736
# std                  1663.191691                  24.005779
# min                     0.000000                   0.000000
# 25%                   196.000000                  10.500000
# 50%                   605.000000                  17.683439
# 75%                  1394.000000                  28.634146
# max                 35188.000000                 871.250000
#
#         within_days_180num_unqsum  within_days_180num_unqmean  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                  2090.805633                   24.740990
# std                   2583.529737                   18.290344
# min                      1.000000                    1.000000
# 25%                    427.000000                   13.490147
# 50%                   1263.000000                   20.583333
# 75%                   2802.000000                   30.577022
# max                  52598.000000                  560.333333
#
#         within_days_180num_unqcount  within_days_180total_secssum  \
# count                  88544.000000                  8.854400e+04
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                      71.289811                 -1.979174e+12
# std                       50.173053                  2.754958e+14
# min                        1.000000                 -7.378698e+16
# 25%                       27.000000                  1.021806e+05
# 50%                       65.000000                  3.145153e+05
# 75%                      108.000000                  7.176428e+05
# max                      180.000000                  1.519852e+07
#
#         within_days_180total_secsmean  within_days_180num_25sum  \
# count                    8.854400e+04              88544.000000
# unique                            NaN                       NaN
# top                               NaN                       NaN
# freq                              NaN                       NaN
# mean                    -2.291994e+10                464.508132
# std                      2.817791e+12                890.415732
# min                     -6.895979e+14                  0.000000
# 25%                      3.180790e+03                 81.000000
# 50%                      4.970085e+03                235.000000
# 75%                      7.747661e+03                567.000000
# max                      1.782986e+05             166936.000000
#
#         within_days_180num_25mean  within_days_180num_50sum  \
# count                88544.000000              88544.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                     5.968142                114.264603
# std                      7.904848                158.377603
# min                      0.000000                  0.000000
# 25%                      2.329249                 22.000000
# 50%                      4.128933                 63.000000
# 75%                      7.290698                147.000000
# max                    932.603352               8311.000000
#
#         within_days_180num_50mean  within_days_180num_75sum  \
# count                88544.000000              88544.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                     1.498918                 72.136554
# std                      1.721930                 96.141760
# min                      0.000000                  0.000000
# 25%                      0.625000                 14.000000
# 50%                      1.070945                 41.000000
# 75%                      1.833333                 95.000000
# max                    104.333333               3287.000000
#
#         within_days_180num_75mean  within_days_180num_985sum  \
# count                88544.000000               88544.000000
# unique                        NaN                        NaN
# top                           NaN                        NaN
# freq                          NaN                        NaN
# mean                     0.902613                  80.350267
# std                      0.912695                 166.964108
# min                      0.000000                   0.000000
# 25%                      0.426950                  14.000000
# 50%                      0.706897                  43.000000
# 75%                      1.128512                 100.000000
# max                     65.500000               19803.000000
#
#         within_days_180num_985mean  within_days_180num_100sum  \
# count                 88544.000000               88544.000000
# unique                         NaN                        NaN
# top                            NaN                        NaN
# freq                           NaN                        NaN
# mean                      0.967418                2124.856648
# std                       1.336536                3129.427760
# min                       0.000000                   0.000000
# 25%                       0.427574                 360.000000
# 50%                       0.727273                1149.000000
# 75%                       1.187500                2663.000000
# max                     133.446429               64190.000000
#
#         within_days_180num_100mean  within_days_365num_unqsum  \
# count                 88544.000000               88544.000000
# unique                         NaN                        NaN
# top                            NaN                        NaN
# freq                           NaN                        NaN
# mean                     24.115101                3896.207400
# std                      23.396972                4890.713126
# min                       0.000000                   1.000000
# 25%                      11.166667                 737.750000
# 50%                      18.196254                2317.000000
# 75%                      29.039801                5258.000000
# max                     710.333333              103640.000000
#
#         within_days_365num_unqmean  within_days_365num_unqcount  \
# count                 88544.000000                 88544.000000
# unique                         NaN                          NaN
# top                            NaN                          NaN
# freq                           NaN                          NaN
# mean                     25.245055                   131.113401
# std                      17.842956                    99.124183
# min                       1.000000                     1.000000
# 25%                      14.224490                    43.000000
# 50%                      21.266667                   115.000000
# 75%                      31.154067                   203.000000
# max                     560.333333                   365.000000
#
#         within_days_365total_secssum  within_days_365total_secsmean  \
# count                   8.854400e+04                   8.854400e+04
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                   -6.041691e+12                  -3.677399e+10
# std                     3.640763e+14                   2.148897e+12
# min                    -7.378698e+16                  -3.617009e+14
# 25%                     1.753236e+05                   3.351469e+03
# 50%                     5.750376e+05                   5.154735e+03
# 75%                     1.347311e+06                   7.914708e+03
# max                     2.993833e+07                   1.549087e+05
#
#         within_days_365num_25sum  within_days_365num_25mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                  859.351520                   6.090492
# std                  2152.429448                   8.587733
# min                     0.000000                   0.000000
# 25%                   145.000000                   2.510204
# 50%                   431.000000                   4.326370
# 75%                  1058.000000                   7.466156
# max                519451.000000                1427.063187
#
#         within_days_365num_50sum  within_days_365num_50mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                  212.907018                   1.541631
# std                   298.543419                   1.634560
# min                     0.000000                   0.000000
# 25%                    39.000000                   0.677632
# 50%                   117.000000                   1.130952
# 75%                   275.000000                   1.888889
# max                 19246.000000                  60.500000
#
#         within_days_365num_75sum  within_days_365num_75mean  \
# count               88544.000000               88544.000000
# unique                       NaN                        NaN
# top                          NaN                        NaN
# freq                         NaN                        NaN
# mean                  133.405527                   0.921047
# std                   179.646957                   0.882435
# min                     0.000000                   0.000000
# 25%                    25.000000                   0.454545
# 50%                    76.000000                   0.733333
# 75%                   175.000000                   1.149123
# max                  8016.000000                  65.500000
#
#         within_days_365num_985sum  within_days_365num_985mean  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                   148.187715                    0.979698
# std                    271.766276                    1.137067
# min                      0.000000                    0.000000
# 25%                     25.000000                    0.454545
# 50%                     78.000000                    0.750000
# 75%                    185.000000                    1.200000
# max                  26622.000000                   86.155340
#
#         within_days_365num_100sum  within_days_365num_100mean  \
# count                88544.000000                88544.000000
# unique                        NaN                         NaN
# top                           NaN                         NaN
# freq                          NaN                         NaN
# mean                  3949.711895                   24.569486
# std                   5839.985612                   22.801391
# min                      0.000000                    0.000000
# 25%                    623.000000                   11.806058
# 50%                   2102.000000                   18.867847
# 75%                   5003.000000                   29.706403
# max                 140785.000000                  647.666667
#
#         within_days_9999num_unqsum  within_days_9999num_unqmean  \
# count                 88544.000000                 88544.000000
# unique                         NaN                          NaN
# top                            NaN                          NaN
# freq                           NaN                          NaN
# mean                   6768.144403                    25.652204
# std                    9203.006883                    17.417302
# min                       1.000000                     1.000000
# 25%                    1002.000000                    14.798119
# 50%                    3584.000000                    21.936890
# 75%                    9046.250000                    31.791510
# max                  234810.000000                   560.333333
#
#         within_days_9999num_unqcount  within_days_9999total_secssum  \
# count                   88544.000000                   8.854400e+04
# unique                           NaN                            NaN
# top                              NaN                            NaN
# freq                             NaN                            NaN
# mean                      222.584850                  -2.994804e+14
# std                       196.804976                   3.620312e+15
# min                         1.000000                  -3.135946e+17
# 25%                        56.000000                   2.145400e+05
# 50%                       169.000000                   8.452459e+05
# 75%                       346.000000                   2.223149e+06
# max                       790.000000                   9.223372e+15
#
#         within_days_9999total_secsmean  within_days_9999num_25sum  \
# count                     8.854400e+04               88544.000000
# unique                             NaN                        NaN
# top                                NaN                        NaN
# freq                               NaN                        NaN
# mean                     -7.498238e+11                1476.962256
# std                       9.459203e+12                3814.395114
# min                      -8.384884e+14                   0.000000
# 25%                       3.373914e+03                 205.000000
# 50%                       5.233477e+03                 681.000000
# 75%                       7.989009e+03                1798.000000
# max                       1.358376e+13              911417.000000
#
#         within_days_9999num_25mean  within_days_9999num_50sum  \
# count                 88544.000000               88544.000000
# unique                         NaN                        NaN
# top                            NaN                        NaN
# freq                           NaN                        NaN
# mean                      6.214718                 367.734708
# std                       8.261136                 548.144978
# min                       0.000000                   0.000000
# 25%                       2.651424                  56.000000
# 50%                       4.500000                 186.000000
# 75%                       7.621627                 468.000000
# max                    1298.314815               37859.000000
#
#         within_days_9999num_50mean  within_days_9999num_75sum  \
# count                 88544.000000               88544.000000
# unique                         NaN                        NaN
# top                            NaN                        NaN
# freq                           NaN                        NaN
# mean                      1.582176                 229.020227
# std                       1.622525                 327.643138
# min                       0.000000                   0.000000
# 25%                       0.722222                  35.000000
# 50%                       1.181818                 119.000000
# 75%                       1.942504                 297.000000
# max                      60.500000               16436.000000
#
#         within_days_9999num_75mean  within_days_9999num_985sum  \
# count                 88544.000000                88544.000000
# unique                         NaN                         NaN
# top                            NaN                         NaN
# freq                           NaN                         NaN
# mean                      0.940062                  254.208992
# std                       0.872478                  440.184627
# min                       0.000000                    0.000000
# 25%                       0.481250                   35.000000
# 50%                       0.757725                  121.000000
# 75%                       1.167134                  313.000000
# max                      65.500000                27315.000000
#
#         within_days_9999num_985mean  within_days_9999num_100sum  \
# count                  88544.000000                88544.000000
# unique                          NaN                         NaN
# top                             NaN                         NaN
# freq                            NaN                         NaN
# mean                       0.992622                 6864.914574
# std                        1.023119                10865.335596
# min                        0.000000                    0.000000
# 25%                        0.478528                  853.000000
# 50%                        0.769231                 3299.000000
# 75%                        1.217949                 8601.250000
# max                       58.358824               387552.000000
#
#         within_days_9999num_100mean  total_plan_days  total_amount_paid  \
# count                  88544.000000     88544.000000       88544.000000
# unique                          NaN              NaN                NaN
# top                             NaN              NaN                NaN
# freq                            NaN              NaN                NaN
# mean                      24.937062       437.796169        2037.669125
# std                       22.230638       241.813007        1234.637258
# min                        0.000000         1.000000           0.000000
# 25%                       12.291667       240.000000         990.000000
# 50%                       19.508859       440.000000        1788.000000
# 75%                       30.343668       615.000000        3193.000000
# max                      647.666667      1690.000000        5908.000000
#
#         amount_paid_per_day  diff_renewal_duration  \
# count          88544.000000           88544.000000
# unique                  NaN                    NaN
# top                     NaN                    NaN
# freq                    NaN                    NaN
# mean               4.602800               2.989858
# std                1.085134              51.117939
# min                0.000000            -420.000000
# 25%                3.936907               0.000000
# 50%                4.898667               0.000000
# 75%                5.164424               0.000000
# max               53.189189             450.000000
#
#         diff_plan_amount_paid_per_day  latest_payment_method_id  \
# count                    88544.000000              88544.000000
# unique                            NaN                       NaN
# top                               NaN                       NaN
# freq                              NaN                       NaN
# mean                        -5.606482                 37.700296
# std                        237.546015                  4.484667
# min                      -9999.000000                  3.000000
# 25%                          0.000000                 36.000000
# 50%                          0.000000                 39.000000
# 75%                          0.000000                 41.000000
# max                          6.000000                 41.000000
#
#         latest_plan_days  latest_plan_list_price  latest_amount_paid  \
# count       88544.000000            88544.000000        88544.000000
# unique               NaN                     NaN                 NaN
# top                  NaN                     NaN                 NaN
# freq                 NaN                     NaN                 NaN
# mean           52.462742              227.611199          227.036185
# std            79.217446              332.886694          333.154660
# min             0.000000                0.000000            0.000000
# 25%            30.000000               99.000000           99.000000
# 50%            30.000000              149.000000          149.000000
# 75%            30.000000              149.000000          149.000000
# max           450.000000             2000.000000         2000.000000
#
#         latest_auto_renew  latest_transaction_date  latest_expire_date  \
# count        88544.000000             8.854400e+04        8.854400e+04
# unique                NaN                      NaN                 NaN
# top                   NaN                      NaN                 NaN
# freq                  NaN                      NaN                 NaN
# mean             0.639874             2.016869e+07        2.016998e+07
# std              0.480039             3.996365e+03        6.095780e+03
# min              0.000000             2.015010e+07        1.970010e+07
# 25%              0.000000             2.017012e+07        2.017021e+07
# 50%              1.000000             2.017020e+07        2.017030e+07
# 75%              1.000000             2.017022e+07        2.017032e+07
# max              1.000000             2.017023e+07        2.017033e+07
#
#         latest_is_cancel  latest_amount_paid_per_day  \
# count       88544.000000                88544.000000
# unique               NaN                         NaN
# top                  NaN                         NaN
# freq                 NaN                         NaN
# mean            0.174659                    4.249737
# std             0.379677                   47.556868
# min             0.000000                -9999.000000
# 25%             0.000000                    3.300000
# 50%             0.000000                    4.966667
# 75%             0.000000                    4.966667
# max             1.000000                    6.000000
#
#         date_featuresdatemax_date_year  date_featuresdatemax_date_month  \
# count                     88544.000000                     88544.000000
# unique                             NaN                              NaN
# top                                NaN                              NaN
# freq                               NaN                              NaN
# mean                       2016.881234                         2.525117
# std                           0.372700                         2.183868
# min                        2015.000000                         1.000000
# 25%                        2017.000000                         2.000000
# 50%                        2017.000000                         2.000000
# 75%                        2017.000000                         2.000000
# max                        2017.000000                        12.000000
#
#         date_featuresdatemax_date_day  date_featuresdatemax_date_absday  \
# count                    88544.000000                      88544.000000
# unique                            NaN                               NaN
# top                               NaN                               NaN
# freq                              NaN                               NaN
# mean                        21.763507                       6234.178363
# std                          8.070249                         94.115610
# min                          1.000000                       5479.000000
# 25%                         17.000000                       6247.000000
# 50%                         26.000000                       6265.000000
# 75%                         28.000000                       6268.000000
# max                         31.000000                       6268.000000
#
#         date_featuresdatemin_date_year  date_featuresdatemin_date_month  \
# count                     88544.000000                     88544.000000
# unique                             NaN                              NaN
# top                                NaN                              NaN
# freq                               NaN                              NaN
# mean                       2015.427177                         4.265992
# std                           0.580881                         3.899945
# min                        2015.000000                         1.000000
# 25%                        2015.000000                         1.000000
# 50%                        2015.000000                         2.000000
# 75%                        2016.000000                         8.000000
# max                        2017.000000                        12.000000
#
#         date_featuresdatemin_date_day  date_featuresdatemin_date_absday
# count                    88544.000000                      88544.000000
# unique                            NaN                               NaN
# top                               NaN                               NaN
# freq                              NaN                               NaN
# mean                        11.133335                       5744.282097
# std                          9.493778                        261.169278
# min                          1.000000                       5479.000000
# 25%                          2.000000                       5481.000000
# 50%                          8.000000                       5710.000000
# 75%                         19.000000                       5959.000000
# max                         31.000000                       6268.000000

# %% [markdown]
# Next, we convert the gender variable (a string) to dummy encoding:

# %%
#Convert gender variable:
dummy = pd.get_dummies(df_fa['gender'])
df_fa = pd.concat([df_fa, dummy], axis=1)
df_fa.drop('gender', axis=1, inplace=True)
"""Note, we're not concerned about collinearity having both a female and a male category,
as there are several cases where both values are 0, presumably because the user did not
supply the information.  Thus, the two columns, male and female, capture the 3 cases:
male, female, and 'not supplied'. """
;
# Out:
# ''

# %% [markdown]
# A couple more quick inspections:

# %%
df_fa.head()
# Out:
#                                               city  bd  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0              13
#
#                                               registration_init_time  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004
#
#                                               is_churn  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=         0
#
#                                               date_featuresdatelistening_tenure  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 35
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                173
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                177
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 22
#
#                                               within_days_1num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1
#
#                                               within_days_1num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          1
#
#                                               within_days_1total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     156.204
#
#                                               within_days_1total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      156.204
#
#                                               within_days_1num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       1
#
#                                               within_days_1num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_1num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_7num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      228
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      243
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      121
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       14
#
#                                               within_days_7num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 32.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.714286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.200000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.000000
#
#                                               within_days_7num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2
#
#                                               within_days_7total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   32731.138
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   60581.740
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   30054.147
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2399.824
#
#                                               within_days_7total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4675.876857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  8654.534286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  6010.829400
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1199.912000
#
#                                               within_days_7num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     140
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      29
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.428571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 5.800000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       5
#
#                                               within_days_7num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 4.142857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 2.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.500000
#
#                                               within_days_7num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 2.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_7num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.400000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  0.000000
#
#                                               within_days_7num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       95
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      238
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_7num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 13.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.600000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.500000
#
#                                               within_days_14num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       512
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       489
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       192
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        17
#
#                                               within_days_14num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.928571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.454545
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   4.250000
#
#                                               within_days_14num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           4
#
#                                               within_days_14total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    98422.408
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   122772.792
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    43518.795
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2630.818
#
#                                               within_days_14total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   7030.172000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8769.485143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3956.254091
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    657.704500
#
#                                               within_days_14num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      301
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       44
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_14num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 21.500000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  4.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.250000
#
#                                               within_days_14num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       71
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7
#
#                                               within_days_14num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.071429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.750000
#
#                                               within_days_14num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       34
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        5
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        4
#
#                                               within_days_14num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.428571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.357143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.000000
#
#                                               within_days_14num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        42
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_14num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   3.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.785714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.000000
#
#                                               within_days_14num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       305
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       476
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       174
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         5
#
#                                               within_days_14num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  21.785714
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  15.818182
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1.250000
#
#                                               within_days_31num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      1044
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       899
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       457
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_31num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.750000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  32.107143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_31num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          28
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          26
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_31total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3158.450
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   178909.861
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   231622.820
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   111841.140
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_31total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    789.612500
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   6169.305552
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8272.243571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4301.582308
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_31num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       33
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      656
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       73
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       80
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_31num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  8.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 22.620690
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.607143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.076923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_31num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      135
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       23
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_31num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4.655172
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.250000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.884615
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_31num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       61
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_31num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.103448
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.392857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_31num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        74
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_31num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.551724
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.500000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_31num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       893
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       456
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_31num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   2.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  19.689655
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  31.892857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.538462
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_90num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      4298
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2396
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1229
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_90num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  58.876712
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  35.235294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  21.189655
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_90num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          73
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          68
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          58
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_90total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   632743.845
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   770040.608
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   287422.839
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_90total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   8667.723904
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  11324.126588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4955.566190
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_90num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2717
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      203
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_90num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 37.219178
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.647059
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.500000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_90num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      393
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       81
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_90num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.383562
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.396552
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_90num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      188
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       55
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_90num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.575342
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.948276
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_90num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       189
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        33
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        60
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_90num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.589041
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.485294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.034483
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_90num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2953
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_90num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  28.684932
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  43.426471
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  19.741379
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_180num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        136
#
#                                               within_days_180num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   13.600000
#
#                                               within_days_180num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           10
#
#                                               within_days_180total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     15562.900
#
#                                               within_days_180total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    1556.290000
#
#                                               within_days_180num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        76
#
#                                               within_days_180num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   7.600000
#
#                                               within_days_180num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        36
#
#                                               within_days_180num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   3.600000
#
#                                               within_days_180num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        22
#
#                                               within_days_180num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.200000
#
#                                               within_days_180num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          7
#
#                                               within_days_180num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    0.700000
#
# ...
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         36
#
#                                               within_days_9999num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    3.600000
#
#                                               within_days_9999num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         22
#
#                                               within_days_9999num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2.200000
#
#                                               within_days_9999num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           7
#
#                                               within_days_9999num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     0.700000
#
#                                               within_days_9999num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        4204
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        4308
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1272
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          21
#
#                                               within_days_9999num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    27.298701
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    39.522936
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    18.434783
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2.100000
#
#                                               total_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=               60
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=              180
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=              180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=              150
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=              150
#
#                                               total_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                258
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                774
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                774
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                596
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                645
#
#                                               amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=             4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=             4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=             4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=             3.973333
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=             4.300000
#
#                                               diff_renewal_duration  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      0
#
#                                               diff_plan_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            0.0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            0.0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            0.0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            0.0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            0.0
#
#                                               latest_payment_method_id  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        30
#
#                                               latest_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                30
#
#                                               latest_plan_list_price  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     129
#
#                                               latest_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 129
#
#                                               latest_auto_renew  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1
#
#                                               latest_transaction_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 20170220
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 20170207
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 20170202
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 20170228
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 20170204
#
#                                               latest_expire_date  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=            20170319
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=            20170306
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=            20170301
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=            20170327
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=            20170303
#
#                                               latest_is_cancel  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 0
#
#                                               latest_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4.966667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    4.300000
#
#                                               date_featuresdatemax_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2017
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2017
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            2017
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            2016
#
#                                               date_featuresdatemax_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                2
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               10
#
#                                               date_featuresdatemax_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             24
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             26
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             26
#
#                                               date_featuresdatemax_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              6264
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              6267
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              6266
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6268
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              6143
#
#                                               date_featuresdatemin_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2016
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2016
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            2016
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            2016
#
#                                               date_featuresdatemin_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                9
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                9
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               10
#
#                                               date_featuresdatemin_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              4
#
#                                               date_featuresdatemin_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              6229
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              6094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              6089
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              6121
#
#                                               female  male
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=       0     0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=       0     0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=       0     0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=       0     0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=       0     0

# %% [markdown]
# The team added a few more features to improve the model, comparing (subtracting) the latest transaction date, latest expiry date, and latest user log date in the cell below:

# %%
#First transform these into datetime, then into 4 components
df_fa['latest_transaction_date'] = pd_to_date(df_fa['latest_transaction_date'])
df_fa['latest_expire_date'] = pd_to_date(df_fa['latest_expire_date'])
split_date_col('latest_transaction_date')
split_date_col('latest_expire_date')

#Now perform the subtraction of all 3 combinations
df_fa['latest_trans_vs_expire'] = df_fa['latest_transaction_date_absday'] - df_fa['latest_expire_date_absday']
df_fa['latest_trans_vs_log'] = df_fa['latest_transaction_date_absday'] - df_fa['date_featuresdatemax_date_absday']
df_fa['latest_log_vs_expire'] = df_fa['date_featuresdatemax_date_absday'] - df_fa['latest_expire_date_absday']

df_fa.head()
# Out:
#                                               city  bd  registered_via  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=     1   0              13
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=     1   0              13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=     1   0              13
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=     1   0              13
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=     1   0              13
#
#                                               registration_init_time  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                20170120
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20160907
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                20160902
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                20161028
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                20161004
#
#                                               is_churn  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=         0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=         0
#
#                                               date_featuresdatelistening_tenure  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                 35
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                173
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                177
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                                 22
#
#                                               within_days_1num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        21
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        17
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         1
#
#                                               within_days_1num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          1
#
#                                               within_days_1total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     156.204
#
#                                               within_days_1total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2633.631
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      271.093
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     1626.704
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      156.204
#
#                                               within_days_1num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       13
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       0
#
#                                               within_days_1num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       1
#
#                                               within_days_1num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        1
#
#                                               within_days_1num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_1num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_1num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         8
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         6
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_7num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      228
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      243
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      121
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       14
#
#                                               within_days_7num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 32.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.714286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.200000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.000000
#
#                                               within_days_7num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2
#
#                                               within_days_7total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   32731.138
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   60581.740
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   30054.147
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    2399.824
#
#                                               within_days_7total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4675.876857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  8654.534286
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  6010.829400
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1199.912000
#
#                                               within_days_7num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     140
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      29
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                20.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.428571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 5.800000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       5
#
#                                               within_days_7num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 4.142857
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 2.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.500000
#
#                                               within_days_7num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       5
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       4
#
#                                               within_days_7num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 2.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 2.000000
#
#                                               within_days_7num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        0
#
#                                               within_days_7num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.400000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  0.000000
#
#                                               within_days_7num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       95
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      238
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      123
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_7num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 13.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 24.600000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.500000
#
#                                               within_days_14num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       512
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       489
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       192
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        17
#
#                                               within_days_14num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.571429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.928571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.454545
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   4.250000
#
#                                               within_days_14num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          14
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           4
#
#                                               within_days_14total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       10.068
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    98422.408
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   122772.792
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    43518.795
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2630.818
#
#                                               within_days_14total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     10.068000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   7030.172000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8769.485143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3956.254091
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    657.704500
#
#                                               within_days_14num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      301
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       44
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        5
#
#                                               within_days_14num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  2.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 21.500000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.285714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  4.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.250000
#
#                                               within_days_14num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       71
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       11
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        7
#
#                                               within_days_14num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.071429
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.142857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.000000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.750000
#
#                                               within_days_14num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       34
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        5
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        4
#
#                                               within_days_14num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.428571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.357143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1.000000
#
#                                               within_days_14num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        42
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         7
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         0
#
#                                               within_days_14num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   3.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.785714
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.636364
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.000000
#
#                                               within_days_14num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       305
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       476
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       174
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         5
#
#                                               within_days_14num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.000000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  21.785714
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  34.000000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  15.818182
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1.250000
#
#                                               within_days_31num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      1044
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       899
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       457
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_31num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.750000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  36.000000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  32.107143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_31num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          29
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          28
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          26
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_31total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3158.450
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   178909.861
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   231622.820
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   111841.140
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_31total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    789.612500
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   6169.305552
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   8272.243571
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4301.582308
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_31num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       33
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      656
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       73
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       80
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_31num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  8.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 22.620690
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.607143
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.076923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_31num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      135
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        7
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       23
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_31num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  4.655172
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.250000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.884615
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_31num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       61
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       11
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_31num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.103448
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.392857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_31num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        74
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        14
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        15
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_31num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.551724
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.500000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   0.576923
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_31num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       571
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       893
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       456
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_31num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   2.250000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  19.689655
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  31.892857
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  17.538462
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_90num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      4298
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2396
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1229
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       136
#
#                                               within_days_90num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  58.876712
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  35.235294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  21.189655
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  13.600000
#
#                                               within_days_90num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          73
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          68
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          58
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          10
#
#                                               within_days_90total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   632743.845
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   770040.608
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   287422.839
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    15562.900
#
#                                               within_days_90total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   8667.723904
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  11324.126588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   4955.566190
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   1556.290000
#
#                                               within_days_90num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2717
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      180
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      203
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       76
#
#                                               within_days_90num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 37.219178
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  2.647059
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  3.500000
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  7.600000
#
#                                               within_days_90num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      393
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       81
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       36
#
#                                               within_days_90num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  5.383562
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1.396552
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  3.600000
#
#                                               within_days_90num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      188
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       32
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       55
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       22
#
#                                               within_days_90num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  2.575342
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  0.470588
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  0.948276
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  2.200000
#
#                                               within_days_90num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       189
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        33
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        60
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         7
#
#                                               within_days_90num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.589041
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.485294
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.034483
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   0.700000
#
#                                               within_days_90num_100sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         9
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      2094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      2953
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      1145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        21
#
#                                               within_days_90num_100mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   1.500000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  28.684932
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  43.426471
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  19.741379
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.100000
#
#                                               within_days_180num_unqsum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         29
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       9218
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       3580
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       1441
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        136
#
#                                               within_days_180num_unqmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   59.857143
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   32.844037
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   20.884058
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   13.600000
#
#                                               within_days_180num_unqcount  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            6
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          154
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          109
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           69
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                           10
#
#                                               within_days_180total_secssum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      3245.638
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   1232770.399
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   1137009.556
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    326268.069
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     15562.900
#
#                                               within_days_180total_secsmean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     540.939667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    8005.002591
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   10431.280330
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4728.522739
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    1556.290000
#
#                                               within_days_180num_25sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        41
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      5289
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       423
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       247
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        76
#
#                                               within_days_180num_25mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   6.833333
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  34.344156
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   3.880734
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   3.579710
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   7.600000
#
#                                               within_days_180num_50sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       838
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        72
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       115
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        36
#
#                                               within_days_180num_50mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   5.441558
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.660550
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.666667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   3.600000
#
#                                               within_days_180num_75sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       410
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        74
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        22
#
#                                               within_days_180num_75mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                   2.662338
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                   0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   1.072464
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                   2.200000
#
#                                               within_days_180num_985sum  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        323
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         58
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         76
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          7
#
#                                               within_days_180num_985mean  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    0.166667
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    2.097403
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    0.532110
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    1.101449
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    0.700000
#
# ...
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                258
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                774
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                774
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                596
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                645
#
#                                               amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=             4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=             4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=             4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=             3.973333
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=             4.300000
#
#                                               diff_renewal_duration  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                      0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                      0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                      0
#
#                                               diff_plan_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            0.0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            0.0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            0.0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            0.0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            0.0
#
#                                               latest_payment_method_id  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                        30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                        30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                        30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                        30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                        30
#
#                                               latest_plan_days  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                30
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                30
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                30
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                30
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                30
#
#                                               latest_plan_list_price  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     129
#
#                                               latest_amount_paid  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 129
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 129
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 129
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 149
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 129
#
#                                               latest_auto_renew  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                  1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  1
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                  1
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  1
#
#                                               latest_is_cancel  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                 0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                 0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                 0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                 0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                 0
#
#                                               latest_amount_paid_per_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                    4.300000
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    4.300000
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    4.300000
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    4.966667
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                    4.300000
#
#                                               date_featuresdatemax_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2017
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2017
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            2017
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            2016
#
#                                               date_featuresdatemax_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                2
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                                2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               10
#
#                                               date_featuresdatemax_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             24
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                             27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                             26
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                             26
#
#                                               date_featuresdatemax_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              6264
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              6267
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              6266
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6268
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              6143
#
#                                               date_featuresdatemin_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            2016
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2016
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            2016
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            2016
#
#                                               date_featuresdatemin_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                                1
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                                9
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                                9
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                               10
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                               10
#
#                                               date_featuresdatemin_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                             20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                             28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              4
#
#                                               date_featuresdatemin_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              6229
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              6094
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              6089
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              6145
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              6121
#
#                                               female  male  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=       0     0
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=       0     0
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=       0     0
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=       0     0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=       0     0
#
#                                               latest_transaction_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                          2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                          2017
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                          2017
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                          2017
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                          2017
#
#                                               latest_transaction_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                              2
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                              2
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                              2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                              2
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                              2
#
#                                               latest_transaction_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                           20
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            2
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                           28
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            4
#
#                                               latest_transaction_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                            6260
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                            6247
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                            6242
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                            6268
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                            6244
#
#                                               latest_expire_date_year  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     2017
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     2017
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     2017
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     2017
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     2017
#
#                                               latest_expire_date_month  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                         3
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                         3
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                         3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                         3
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                         3
#
#                                               latest_expire_date_day  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                      19
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       6
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       1
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                      27
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       3
#
#                                               latest_expire_date_absday  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                       6287
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                       6274
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                       6269
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                       6295
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                       6271
#
#                                               latest_trans_vs_expire  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                     -27
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                     -27
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                     -27
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                     -27
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                     -27
#
#                                               latest_trans_vs_log  \
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   -4
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                  -20
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                  -24
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                    0
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  101
#
#                                               latest_log_vs_expire
# msno
# mKfgXQAmVeSKzN4rXW37qz0HbGCuYBspTBM3ONXZudg=                   -23
# AFcKYsrudzim8OFa+fL/c9g5gZabAbhaJnoM0qmlJfo=                    -7
# qk4mEZUYZq+4sQE7bzRYKc5Pvj+Xc7Wmu25DrCzltEU=                    -3
# G2UGNLph2J6euGmZ7WIa1+Kc+dPZBJI0HbLPu5YtrZw=                   -27
# EqSHZpMj5uddJvv2gXcHvuOKFOdS5NN6RalHfzEhhaI=                  -128

# %%
df_fa.shape
# Out:
# (88544, 159)

# %% [markdown]
# # 7. Quick Exploratory Data Analysis
#
# Next, we perform some quick EDA on our data.

# %% [markdown]
# ## Combined Dataset

# %%
color = ['red', 'blue']
plt.figure()
for color, i, name in zip(color, [0,1], ['no_churn', 'churn']):
    plt.scatter(df_fa[df_fa['is_churn'] == i]['date_featuresdatelistening_tenure'],
               df_fa[df_fa['is_churn'] == i]['within_days_7num_unqmean'], color = color, alpha = 0.2, label = name)
plt.legend(loc = 'best')
plt.xlabel('Listening Tenure')
plt.ylabel('Mean Number of Unique listening Periods in the last 7 days')
# Out:
# Text(0,0.5,'Mean Number of Unique listening Periods in the last 7 days')

# %% [markdown]
# Looking at the above plot, we can see that overall people who churn have low numbers of unique plays, meaning they aren't using the music service. We can also see a spike in number of unique plays for users who have a long tenure (>700 days). Intuitively this makes sense as users who are commited to the service (have used the service for a long time) may have developed lifestyle patterns where they use the service while driving/working/etc.

# %%
avg_price_no_churn = round(df_fa[df_fa['is_churn'] == 0]['amount_paid_per_day'].mean(), 2)
avg_price_is_churn = round(df_fa[df_fa['is_churn'] == 1]['amount_paid_per_day'].mean(), 2)
print('Avg cost/day for no churn: %.2f' %avg_price_no_churn)
print('Avg cost/day for churn: %.2f' %avg_price_is_churn)
# Out:
# Avg cost/day for no churn: 4.54
# Avg cost/day for churn: 4.67

# %% [markdown]
# For users who churn, we can see that they tend to spend more per day on the music subscription service. Our analysis will end with an economic analysis which uses the predictions to model how much incentive should be offered to specific users. This will hopefully help incentivize those customers that will churn and prevent it.

# %%
corr = df_fa.iloc[:, 8:99:15].corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, mask=mask)

# %% [markdown]
# The correlation plot shows that there is correlation amongst the number of unique songs played within the last X number of days (where if the two X values are close together the correlation tends to be higher). This makes sense and is what was expected.

# %%
mean_col = df_fa.iloc[:, 7:98:15].mean()
mean_col
# Out:
# within_days_1num_unqmean      20.698794
# within_days_7num_unqmean      21.900082
# within_days_14num_unqmean     22.383794
# within_days_31num_unqmean     23.271521
# within_days_90num_unqmean     24.238664
# within_days_180num_unqmean    24.740990
# within_days_365num_unqmean    25.245055
# dtype: float64

# %%
#plt.plot_date(reg_time, df_fa['within_days_7total_secsmean'], )
color = ['red', 'blue']
for color, i, name in zip(color, [0,1], ['no_churn', 'churn']):
    plt.plot_date(pd.to_datetime(df_fa[df_fa['is_churn'] == i]['registration_init_time'], format = '%Y%m%d'),
               df_fa[df_fa['is_churn'] == i]['within_days_7total_secsmean']/(60*60), color = color, alpha = 0.2, label = name)
plt.legend(loc = 'best')
plt.xlabel('Registration Date')
plt.ylim([0,20])
plt.ylabel('Number of Seconds (Avg) Listed during last 7 days')
# Out:
# Text(0,0.5,'Number of Seconds (Avg) Listed during last 7 days')

# %% [markdown]
# This plot shows the Registration Date vs Avg seconds listened over past 7 days. The intent will be to change this to transaction date as this will more accurately reflect when the user ends service. We can see a trend in more churn occuring in the last 4 years of the dataset. This could be due to an increased level of users however (same proportion of churn).

# %%
df_fa['registration_time'] = pd.to_datetime(df_fa['registration_init_time'], format = '%Y%m%d').map(lambda x: x.year)
reg_count = []
thirty_day_churn = []
for year in range(2005, 2018):
    reg_count.append(sum(df_fa['registration_time'] == year))
    thirty_day_churn.append(len(df_fa[(df_fa['registration_time'] == year) & (df_fa['date_featuresdatelistening_tenure'] < 30) & (df_fa['is_churn'] == 1)])/sum(df_fa['registration_time'] == year))
plt.bar(range(2005, 2018), reg_count)
plt.xlabel('Year of Registration')
plt.title('Registration Count Per Year')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.bar(range(2005, 2018), thirty_day_churn)
plt.xlabel('Year')
plt.title('Proportion of 30 day Churn to Total Registration')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# This statistic shows that there is a high level of churn recently for users who are using a trial subscription, or who a very short duration subscription. From a business perspective this is concerning, because it means that a very high level of churn is occuring, and the problem needs to be solved to reduce churn levels back. The sharp spike may have been when the company started offering 30 days subscriptions or some other factor that has caused increased churn for customers with less than 30 day subscriptionps.

# %%
plt.hist(df_fa['date_featuresdatemax_date_month'])
plt.title('Histogram of the last listen date')
plt.show()

# %% [markdown]
# The dataset (from the dataset description) was collected to include churn statistics for the months of February and March. We can see here a large peak for the month of February, which intuitively makes sense because users are utilizing the service often and most recently listened in the month in which the data was collected.

# %%
print('Is Latest Cancel and Is Churn Correlation: %0.4f' %np.corrcoef(df_fa['latest_is_cancel'], df_fa['is_churn'])[0,1])
# Out:
# Is Latest Cancel and Is Churn Correlation: 0.4328

# %% [markdown]
# Intuitively we had thought there would be a very high correlation between these two variables. However we can see here that, while there is decent correlation between the two variables, they are not perfectly aligned. This is due to the times when a user cancels their service but does not churn (changes plan type, etc).

# %% [markdown]
# ## User Logs EDA

# %%
user_logs['num_unq'].groupby(user_logs['date'].dt.weekday_name).count().plot(kind = 'bar', title = 'Unique Play Count Grouped by Weekday')

# %% [markdown]
# The figure above looks at listening behavior grouped by the day of the week. We can see that listening is fairly consitent across all days of the week. The above plot looks at listening counts, but doesn't analyze how long a user is listening for, we can look at the total seconds feature included in the dataset to determine this.

# %%
#This cell takes a long time to plot, print statistics to screen instead
user_logs.groupby(user_logs['date'].dt.weekday_name)['total_secs'].sum()
# Out:
# date
# Friday      -4.334985e+18
# Monday      -3.892263e+18
# Saturday    -3.431094e+18
# Sunday      -3.855369e+18
# Thursday    -3.919933e+18
# Tuesday     -3.615562e+18
# Wednesday   -3.486435e+18
# Name: total_secs, dtype: float64

# %% [markdown]
# There is some odd behavior here, where all of the sums are large negative values. We need to analyze the column itself in order to determine why this odd behavior is observed.

# %%
user_logs['total_secs'].describe()
# Out:
# count    1.971063e+07
# mean    -1.346260e+12
# std      1.116172e+14
# min     -9.223372e+15
# 25%      1.966237e+03
# 50%      4.703210e+03
# 75%      1.028291e+04
# max      9.223372e+15
# Name: total_secs, dtype: float64

# %% [markdown]
# The mean value for this column is in fact negative, which intuitively doesn't make sense as it is not possible to listen to a song a for a negative time period. Further analysis regarding the method in which the software calculates total_secs will be important to better understand why negative values are being written to the database.
#
# To further explore the total seconds columns, below we analyze the sum of the total seconds by user.

# %%
#This cell takes a long time to plot, print statistics to screen instead
user_logs['total_secs'].groupby(user_logs['msno'], sort = False).sum().describe()
# Out:
# count    8.855000e+04
# mean    -2.996684e+14
# std      3.620704e+15
# min     -3.135946e+17
# 25%      2.145492e+05
# 50%      8.453256e+05
# 75%      2.223251e+06
# max      9.223372e+15
# Name: total_secs, dtype: float64

# %% [markdown]
# We continue to see negative values, even when summing over the total listening time for a specific user. This behavior is strange and now well understood. Further investigation into the matter will be necessary to determine why negative listening times are computed.

# %%
corr = user_logs.iloc[:, 2:7].corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, mask=mask)

# %% [markdown]
# This correlation plot anaylzes the correlation between the num columns in the dataset. From the definition at the start of this notebook, these columns represent the songs that have been played to a certain proportion of the total song length (25%, 50%, etc). Here we can see relatively low correlation between the columns.
#
# The higher listening buckets do not factor in songs that fall below the bucket cutoff (ie for the num_50 bucket it doesn't count a song if it is played <50%, but rather 25-50% of the time). We found this behavior insteresting and wanted to further analyze by plotting a bar chart grouped by these columns.

# %%
sum_num = []
cols = []
for col in user_logs.iloc[:,2:7].columns:
    sum_num.append(user_logs[col].sum())
    cols.append(col)
    
plt.bar(np.arange(len(sum_num)), sum_num)
plt.xticks(np.arange(len(sum_num)), cols)
plt.title('Sum of Proportion Song Listened To')
# Out:
# Text(0.5,1,'Sum of Proportion Song Listened To')

# %% [markdown]
# We can see that num_100 (or listening to the entire song) is by far the most popular method. Num_25 (or less than 25% listened to) was the second most popular column. Intuitively this makes sense as a user is most likely either to like a song and listen to the whole thing, or not like a song and quickly switch to a new song.

# %% [markdown]
# ## Members EDA

# %%
members['gender'].groupby(members['gender']).count().plot(kind = 'bar', title = 'Members grouped by gender')

# %%
print('Proportion of gender column = N/A: %0.4f' %(members['gender'].isnull().sum()/len(members)))
# Out:
# Proportion of gender column = N/A: 0.4843

# %% [markdown]
# Breakdown by gender, we can see that there are overall a larger proportion of males that utilize the kkbox dataset. Additionally we can see that over 48% of this column is N/A values (meaning that the user didn't supply their gender). This has been accounted for in the combined dataset by separating into two colums of 'male' and 'female' and capturing data in binary format.

# %%
members['city'].groupby(members['city']).count().plot(kind = 'bar', title = 'Count by city')

# %% [markdown]
# We can see that overall city = 1 has a significantly higher proportion of users, than any other city. The mapping between numeric and actual city names isn't provided, however from an ML perspective this is alright, however for business purposes it would be preferable to have the city names.

# %%
members['bd'].groupby(members['bd']).count().plot(kind = 'bar', title = 'Count by birthdate')

# %% [markdown]
# The birthdate column has a large peak of entries at the 0 value (presumably not provided by user). Below we filter out the zero value to look at this distribution of birthdays.

# %%
members['bd'].groupby(members['bd']).count().plot(kind = 'bar', title = 'Count by birthdate Filtered')
plt.xlim([3,100])
plt.ylim([0,3000])
plt.show()

# %% [markdown]
# The distribution of provided birthdays appears to be skewed slightly. From the first plot it was hard to determine the range of entries, below we use the describe function to look at the birthday column. From the data provided we see that there are negative values for the birthate (min = -49) which is odd and needs to be further understood. It would also be helpful to know how this integer is defined (presumably days since a specifc date).

# %%
members['bd'].describe()
# Out:
# count    89473.000000
# mean        14.915069
# std         18.416087
# min        -49.000000
# 25%          0.000000
# 50%         17.000000
# 75%         27.000000
# max       1051.000000
# Name: bd, dtype: float64

# %% [markdown]
# The members table provides information about each of the members subscribed to the KKBox service. Through our EDA we noted that there were a few columns with dispraportionately high values, which could make analysis using a machine learning algorithm difficult, as this one common value may make it difficult to discern information from the other data. By including a high number of features, our model will hopefully overcome this difficulty and accurately predict churn.
#
# Moving forward it is preferrable to better understand the data sources and computation and clean up the data collection as best as possible.

# %% [markdown]
# ## Transactions EDA
#
# The transactions table contains information related to the subscription to KKBox, including the plan list price, the actual price the user paid as well as payment methods and dates. For payment method, the column is contains integers that map to a specific type of payment, we have not been granted access to the mapping, however from an ML perspective, we can continue to carry out models. When deriving business insight however, access to the mapping of this column will be important.

# %%
transactions['payment_method_id'].groupby(transactions['payment_method_id']).count().plot(kind = 'bar', title = 'Count by payment type')

# %% [markdown]
# From the plot above we can see that payment method 41 is by far the most popular.

# %%
transactions['plan_list_price'].groupby(transactions['plan_list_price']).count().plot(kind = 'bar', title = 'Count by plan list price')

# %% [markdown]
# Above we analyze the popularity of specific plans on kkbox. From their website it appears that there is a free tier, monthly and yearly tiers (this information is as of todays date (4/21/2018) however we do not know the specific plan offerings for the period of data collection for this analysis.
#
# From the plot above we can see there is an overwhelmingly popular plan price at approximately 149.

# %%
transactions['prop_collected'] = round(transactions['actual_amount_paid'] / transactions['plan_list_price'], 3)
transactions['prop_collected'].groupby(transactions['prop_collected']).count().plot(kind = 'bar', title = 'Count by Proportion of Bill Collected')

# %% [markdown]
# There are two columns in the table that analyze the plan cost and amount collected. We wanted to look and see the distribution of memberships that do not collect the total price of the plan. From above we can see that most plans are fully paid, there is an infinity value which is most likely an error (plan list price of 0 presumably), and there is a peak at 80%

# %%
transactions['transaction_date'] = pd_to_date(transactions['transaction_date'])
transactions['is_cancel'].groupby(transactions['transaction_date'].dt.month).sum().plot(kind = 'bar', title = 'Is Cancel by Month')

# %% [markdown]
# Our team next wanted to look at the is_cancel category, which has some correlation with churn. By month we can see that users peaked in January and especially February. It would be interesting to see how this correlates to churn (as is_cancel isn't perfectly correlated). If there is a seasonality to churn, then it would be important for predicting churn, and providing business insight to offer incentives to users who's memberships expire in this timeframe to renew.

# %%
print('Is Latest Cancel and Is Auto Renew: %0.4f' %np.corrcoef(transactions['is_cancel'], transactions['is_auto_renew'])[0,1])
# Out:
# Is Latest Cancel and Is Auto Renew: 0.0806

# %% [markdown]
# Our team had thought that the cancel and auto renew categories would be negatively correlated (if a user was on an auto renew membership, they may not pay as much attention and forget to cancel/change membership). From the covariance we can see that there is almost no correlation between the two features.
#
# The transactions

# %% [markdown]
# # 8. Writing Output
#
# Having extracted our features and performing some data manipulation, we will now write the features file to a .pkl file, allowing us to use this output in the second notebook without having to run all the code above.

# %%
#Write all features to pkl file
df_fa.to_pickle('df_fa.pkl')
